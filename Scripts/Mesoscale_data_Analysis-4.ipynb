# %% [markdown]
# # Reading The Data
# - Using pynwb

# %%
from pynwb import NWBHDF5IO, NWBFile, TimeSeries
from pynwb.behavior import Position, SpatialSeries
from pynwb.epoch import TimeIntervals
from pynwb.file import Subject
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import animation
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from itertools import count

with NWBHDF5IO("sub-440957_ses-20190213T145027_behavior+ecephys+ogen.nwb", "r") as io:
    read_nwbfile = io.read()
    print(read_nwbfile.acquisition)
# Out:
# {'BehavioralEvents': BehavioralEvents pynwb.behavior.BehavioralEvents at 0x1647736945056
# Fields:
#   time_series: {
#     delay_start_times <class 'pynwb.base.TimeSeries'>,
#     delay_stop_times <class 'pynwb.base.TimeSeries'>,
#     go_start_times <class 'pynwb.base.TimeSeries'>,
#     go_stop_times <class 'pynwb.base.TimeSeries'>,
#     left_lick_times <class 'pynwb.base.TimeSeries'>,
#     photostim_start_times <class 'pynwb.base.TimeSeries'>,
#     photostim_stop_times <class 'pynwb.base.TimeSeries'>,
#     presample_start_times <class 'pynwb.base.TimeSeries'>,
#     presample_stop_times <class 'pynwb.base.TimeSeries'>,
#     right_lick_times <class 'pynwb.base.TimeSeries'>,
#     sample_start_times <class 'pynwb.base.TimeSeries'>,
#     sample_stop_times <class 'pynwb.base.TimeSeries'>,
#     trialend_start_times <class 'pynwb.base.TimeSeries'>,
#     trialend_stop_times <class 'pynwb.base.TimeSeries'>
#   }
# , 'BehavioralTimeSeries': BehavioralTimeSeries pynwb.behavior.BehavioralTimeSeries at 0x1647737307536
# Fields:
#   time_series: {
#     Camera0_side_JawTracking <class 'pynwb.base.TimeSeries'>,
#     Camera0_side_NoseTracking <class 'pynwb.base.TimeSeries'>,
#     Camera0_side_TongueTracking <class 'pynwb.base.TimeSeries'>
#   }
# }

# %% [markdown]
# # Exploring functionalies of nwb module

# %%
#!pip install nwbwidgets
from nwbwidgets import nwb2widget

io = NWBHDF5IO("sub-440957_ses-20190213T145027_behavior+ecephys+ogen.nwb", mode="r")
nwbfile = io.read()

nwb2widget(nwbfile)

#Suppose to give overall structure of nwb file but encountering unexpected error.
# Out:
# VBox(children=(HBox(children=(Label(value='session_description:', layout=Layout(max_height='40px', max_width='…

# %%
nwbfile.subject
# Out:
# subject pynwb.file.Subject at 0x1647835917664
# Fields:
#   age__reference: birth
#   date_of_birth: 2018-10-09 00:00:00-05:00
#   description: SC016
#   sex: M
#   species: Mus musculus
#   subject_id: 440957

# %%
trials_df = nwbfile.trials.to_dataframe()
trials_df
# Out:
#      start_time  stop_time  trial photostim_onset photostim_power  \
# id
# 0        0.0000     5.2512      1             N/A             N/A
# 1        9.4959    14.3958      2             N/A             N/A
# 2       16.1851    20.9083      3             N/A             N/A
# 3       22.6976    27.5231      4             N/A             N/A
# 4       29.3136    34.2297      5             N/A             N/A
# ..          ...        ...    ...             ...             ...
# 496   3487.0914  3491.8707    497             N/A             N/A
# 497   3494.1904  3499.0391    498             N/A             N/A
# 498   3501.9728  3505.9265    499             N/A             N/A
# 499   3508.2258  3513.2005    500             N/A             N/A
# 500   3516.6514  3521.5281    501             N/A             N/A
#
#     photostim_duration  trial_uid         task  task_protocol  \
# id
# 0                  N/A          1  audio delay              1
# 1                  N/A          2  audio delay              1
# 2                  N/A          3  audio delay              1
# 3                  N/A          4  audio delay              1
# 4                  N/A          5  audio delay              1
# ..                 ...        ...          ...            ...
# 496                N/A        497  audio delay              1
# 497                N/A        498  audio delay              1
# 498                N/A        499  audio delay              1
# 499                N/A        500  audio delay              1
# 500                N/A        501  audio delay              1
#
#     trial_instruction early_lick outcome  auto_water  free_water
# id
# 0               right      early     hit           0           0
# 1               right   no early     hit           0           0
# 2               right   no early     hit           0           0
# 3               right   no early  ignore           0           0
# 4               right   no early     hit           0           0
# ..                ...        ...     ...         ...         ...
# 496             right   no early     hit           0           0
# 497             right   no early     hit           0           0
# 498              left   no early    miss           0           0
# 499              left   no early     hit           0           0
# 500              left   no early     hit           0           0
#
# [501 rows x 14 columns]

# %%
units_df = nwbfile.units.to_dataframe()
units_df
# Out:
#      unit  sampling_rate unit_quality  unit_posx  unit_posy    unit_amp  \
# id
# 0       0          30000         good       27.0        0.0   47.460320
# 1       1          30000        multi       59.0        0.0   88.335129
# 2       2          30000        multi       59.0        0.0  117.231140
# 3       3          30000         good       59.0        0.0  218.360166
# 4       4          30000         good       59.0        0.0  406.947115
# ..    ...            ...          ...        ...        ...         ...
# 962   381          30000         good       59.0     1360.0   67.038066
# 963   383          30000        multi       27.0     1760.0   98.380335
# 964   384          30000        multi       27.0     1760.0  109.878701
# 965   385          30000         good       11.0      980.0  204.625000
# 966   386          30000        multi       27.0     1760.0  135.575064
#
#       unit_snr  isi_violation  avg_firing_rate  drift_metric  ...  \
# id                                                            ...
# 0     3.216268       0.137601         0.806964      0.486110  ...
# 1     4.629063       0.000000         0.008220      0.041734  ...
# 2     5.440247       1.000000         2.846620      0.681476  ...
# 3    10.420378       0.020564         3.917470      0.808959  ...
# 4    19.863375       0.000000         3.037950      0.503042  ...
# ..         ...            ...              ...           ...  ...
# 962   3.002982       0.051910         1.772080      0.629746  ...
# 963   4.532427       0.000000         0.011621      0.062731  ...
# 964   4.584050       0.000000         0.021542      0.065425  ...
# 965   3.955917       0.000000         0.021258      0.127767  ...
# 966   6.371136       0.000000         0.027494      0.031431  ...
#
#      velocity_below  classification               anno_name  \
# id
# 0               NaN      unlabelled
# 1               NaN      unlabelled
# 2               NaN      unlabelled
# 3               NaN      unlabelled
# 4               NaN            good  Dorsal peduncular area
# ..              ...             ...                     ...
# 962        2.060330      unlabelled
# 963        0.000000      unlabelled
# 964        1.373550      unlabelled
# 965       -0.850294      unlabelled
# 966             NaN      unlabelled
#
#                                         is_good_trials  \
# id
# 0    [True, True, True, True, True, True, True, Tru...
# 1    [True, True, True, True, True, True, True, Tru...
# 2    [True, True, True, True, True, True, True, Tru...
# 3    [True, True, True, True, True, True, True, Tru...
# 4    [True, True, True, True, True, True, True, Tru...
# ..                                                 ...
# 962  [True, True, True, True, True, True, True, Tru...
# 963  [True, True, True, True, True, True, True, Tru...
# 964  [True, True, True, True, True, True, True, Tru...
# 965  [True, True, True, True, True, True, True, Tru...
# 966  [True, True, True, True, True, True, True, Tru...
#
#                                            spike_times  \
# id
# 0    [0.05187849792484123, 0.12474561697487196, 0.1...
# 1    [350.9674507314316, 487.72716589600077, 1517.2...
# 2    [0.039711755722983355, 0.08944539781934502, 0....
# 3    [39.29803355766251, 80.28907420963154, 80.4640...
# 4    [0.2593131190814475, 0.5323148139669702, 0.702...
# ..                                                 ...
# 962  [0.8200646624999663, 1.5972081850397382, 2.576...
# 963  [238.4006415427377, 829.5028515161549, 2033.18...
# 964  [883.375443383233, 1081.8716938753976, 1082.14...
# 965  [713.8350851570564, 831.3627425680392, 898.045...
# 966  [324.58109481023126, 386.06385698355535, 387.8...
#
#                                          obs_intervals  \
# id
# 0    [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 1    [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 2    [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 3    [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 4    [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# ..                                                 ...
# 962  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 963  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 964  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 965  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 966  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
#
#                                             electrodes  \
# id
# 0                                                 l...
# 1                                                 l...
# 2                                                 l...
# 3                                                 l...
# 4                                                 l...
# ..                                                 ...
# 962                                                ...
# 963                                                ...
# 964                                                ...
# 965                                                ...
# 966                                                ...
#
#                                        electrode_group  \
# id
# 0    17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 1    17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 2    17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 3    17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 4    17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# ..                                                 ...
# 962  18005107871 1-384 pynwb.ecephys.ElectrodeGroup...
# 963  18005107871 1-384 pynwb.ecephys.ElectrodeGroup...
# 964  18005107871 1-384 pynwb.ecephys.ElectrodeGroup...
# 965  18005107871 1-384 pynwb.ecephys.ElectrodeGroup...
# 966  18005107871 1-384 pynwb.ecephys.ElectrodeGroup...
#
#                                          waveform_mean  waveform_sd
# id
# 0    [0.6668203371970496, 0.44701659641728136, 0.91...        [nan]
# 1    [2.990301724137931, 3.636853448275862, 4.60668...        [nan]
# 2    [0.5673261226725081, 0.45694140197152244, 0.37...        [nan]
# 3    [3.418364119433198, 2.9913651315789473, 2.7375...        [nan]
# 4    [10.451923076923077, 9.947115384615385, 9.7596...        [nan]
# ..                                                 ...          ...
# 962  [-3.602139261744967, -3.3819211409395975, -2.7...        [nan]
# 963  [-6.059451219512195, -5.201981707317073, -4.28...        [nan]
# 964  [-1.1101973684210527, -4.625822368421052, -6.3...        [nan]
# 965  [-1.90625, -3.71875, -5.0625, -6.8125, -5.4687...        [nan]
# 966  [-2.222938144329897, -2.2712628865979383, -1.6...        [nan]
#
# [967 rows x 39 columns]

# %%
import ast

# %%
units_df.electrodes.apply(lambda x: len(x)).value_counts()
units_df.electrodes.apply(lambda x: type(x)).value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>    967
# Name: electrodes, dtype: int64

# %%
units_df.electrodes.apply(lambda x: ast.literal_eval(x.location.values[0])['brain_regions']).value_counts()
# Out:
# right Striatum    359
# left Striatum     315
# right ALM         293
# Name: electrodes, dtype: int64

# %%
ast.literal_eval(units_df.electrodes.values[800]["location"].values[0])
#units_df.electrodes[150].reset_index().x.values

#Accessing part-of-the-brain(Need to know unique part of brains) & Co-ordination (yet to done)
# Out:
# {'brain_regions': 'right Striatum',
#  'skull_reference': 'Bregma',
#  'ap_location': '0.00',
#  'ml_location': '2500.00',
#  'depth': '-4400.00',
#  'theta': '10.00',
#  'phi': '0.00',
#  'beta': '60.00'}

# %%
#Querying the data as per the need (Only Successful attempts are being considered here)
trials = trials_df.query("photostim_onset != 'N/A' and (outcome == 'hit' or outcome == 'miss')")
units = units_df.query("classification == 'good'").reset_index()
units
# Out:
#       id  unit  sampling_rate unit_quality  unit_posx  unit_posy    unit_amp  \
# 0      4     4          30000         good       59.0        0.0  406.947115
# 1     14    15          30000         good       11.0      180.0  109.976708
# 2     91    98          30000         good       43.0     1060.0   61.662834
# 3     95   102          30000         good       43.0     1100.0  104.672281
# 4    102   109          30000         good       11.0     1140.0  248.184540
# ..   ...   ...            ...          ...        ...        ...         ...
# 165  927   346          30000         good       43.0      660.0  125.645380
# 166  941   360          30000         good       27.0     1160.0   98.288499
# 167  942   361          30000         good       43.0     1300.0  145.210701
# 168  951   370          30000         good       59.0     1760.0  138.066665
# 169  958   377          30000        multi       59.0     3520.0   65.266432
#
#       unit_snr  isi_violation  avg_firing_rate  ...  velocity_below  \
# 0    19.863375       0.000000         3.037950  ...             NaN
# 1     5.275242       0.073159         4.653290  ...        0.000000
# 2     2.976889       0.006073        10.119800  ...       -2.964560
# 3     5.831190       0.014125         2.355700  ...       -2.174780
# 4    12.069299       0.000000         2.058930  ...        0.343386
# ..         ...            ...              ...  ...             ...
# 165   2.642676       0.035332         4.761540  ...             NaN
# 166   2.642417       0.000000         0.329643  ...        0.000000
# 167   5.814128       0.026635         8.970930  ...             NaN
# 168   6.520817       0.028408         4.732630  ...       -0.686776
# 169   3.423314       0.150778        13.983300  ...        0.727656
#
#      classification                                        anno_name  \
# 0              good                           Dorsal peduncular area
# 1              good                                  Olfactory areas
# 2              good                         Prelimbic area, layer 6b
# 3              good                         Prelimbic area, layer 6b
# 4              good                         Prelimbic area, layer 6a
# ..              ...                                              ...
# 165            good                                     Caudoputamen
# 166            good                                     Caudoputamen
# 167            good                                     Caudoputamen
# 168            good                                     Caudoputamen
# 169            good  Primary somatosensory area, upper limb, layer 4
#
#                                         is_good_trials  \
# 0    [True, True, True, True, True, True, True, Tru...
# 1    [True, True, True, True, True, True, True, Tru...
# 2    [True, True, True, True, True, True, True, Tru...
# 3    [True, True, True, True, True, True, True, Tru...
# 4    [True, True, True, True, True, True, True, Tru...
# ..                                                 ...
# 165  [True, True, True, True, True, True, True, Tru...
# 166  [True, True, True, True, True, True, True, Tru...
# 167  [True, True, True, True, True, True, True, Tru...
# 168  [True, True, True, True, True, True, True, Tru...
# 169  [True, True, True, True, True, True, True, Tru...
#
#                                            spike_times  \
# 0    [0.2593131190814475, 0.5323148139669702, 0.702...
# 1    [0.25401308617707663, 0.35208036167807855, 0.4...
# 2    [0.0529451712137714, 0.07537864382158022, 0.10...
# 3    [0.08804538912762405, 3.566700319110314, 10.15...
# 4    [0.1536791299370983, 0.3191468238823649, 1.450...
# ..                                                 ...
# 165  [0.052021259272768905, 0.40975928294510444, 0....
# 166  [1.8037108925173861, 18.189753021328954, 26.13...
# 167  [0.050587907146612654, 0.21105667773537728, 1....
# 168  [1.7526102225313918, 2.269717002370093, 2.2909...
# 169  [0.06432142054141332, 0.20048987252627093, 0.3...
#
#                                          obs_intervals  \
# 0    [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 1    [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 2    [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 3    [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 4    [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# ..                                                 ...
# 165  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 166  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 167  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 168  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 169  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
#
#                                             electrodes  \
# 0                                                 l...
# 1                                                 l...
# 2                                                  ...
# 3                                                  ...
# 4                                                  ...
# ..                                                 ...
# 165                                                ...
# 166                                                ...
# 167                                                ...
# 168                                                ...
# 169                                                ...
#
#                                        electrode_group  \
# 0    17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 1    17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 2    17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 3    17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 4    17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# ..                                                 ...
# 165  18005107871 1-384 pynwb.ecephys.ElectrodeGroup...
# 166  18005107871 1-384 pynwb.ecephys.ElectrodeGroup...
# 167  18005107871 1-384 pynwb.ecephys.ElectrodeGroup...
# 168  18005107871 1-384 pynwb.ecephys.ElectrodeGroup...
# 169  18005107871 1-384 pynwb.ecephys.ElectrodeGroup...
#
#                                          waveform_mean  waveform_sd
# 0    [10.451923076923077, 9.947115384615385, 9.7596...        [nan]
# 1    [-0.016983695652173912, -0.19652562111801242, ...        [nan]
# 2    [1.0679183467741935, 1.3112714213709677, 1.240...        [nan]
# 3    [1.3367491883116882, 1.1515827922077921, 0.895...        [nan]
# 4    [2.0469094162995596, 1.9797976321585904, 1.778...        [nan]
# ..                                                 ...          ...
# 165  [2.519116531850354, 2.3508594539939334, 1.9408...        [nan]
# 166  [1.6349871134020617, 1.5101481958762886, 1.872...        [nan]
# 167  [0.31960227272727276, 0.6297348484848485, 0.63...        [nan]
# 168  [1.492561037639878, 2.2030773143438456, 2.4987...        [nan]
# 169  [-0.1519756838905775, -0.1353533434650456, 0.0...        [nan]
#
# [170 rows x 40 columns]

# %%
trials
# Out:
#      start_time  stop_time  trial photostim_onset photostim_power  \
# id
# 31     202.9057   206.7780     32           2.046           5.500
# 37     241.5566   246.3362     38           1.816           5.500
# 39     253.9740   258.9920     40           2.058           5.500
# 41     266.5867   270.3717     42           1.830           5.500
# 42     272.2012   276.1265     43           1.935           5.500
# ..          ...        ...    ...             ...             ...
# 453   3162.8479  3167.6416    454           1.880           5.500
# 456   3184.1009  3189.0616    457           1.977           5.500
# 470   3289.8850  3293.8086    471           1.958           5.500
# 473   3310.3812  3315.3121    474           2.053           5.500
# 495   3479.8001  3484.5889    496           1.977           5.500
#
#     photostim_duration  trial_uid         task  task_protocol  \
# id
# 31              0.5000         32  audio delay              1
# 37              0.5000         38  audio delay              1
# 39              0.5000         40  audio delay              1
# 41              0.5000         42  audio delay              1
# 42              0.5000         43  audio delay              1
# ..                 ...        ...          ...            ...
# 453             0.5000        454  audio delay              1
# 456             0.5000        457  audio delay              1
# 470             0.5000        471  audio delay              1
# 473             0.5000        474  audio delay              1
# 495             0.5000        496  audio delay              1
#
#     trial_instruction early_lick outcome  auto_water  free_water
# id
# 31               left   no early    miss           0           0
# 37               left   no early     hit           0           0
# 39               left   no early     hit           0           0
# 41              right   no early    miss           0           0
# 42              right   no early    miss           0           0
# ..                ...        ...     ...         ...         ...
# 453              left   no early     hit           0           0
# 456              left   no early     hit           0           0
# 470             right   no early    miss           0           0
# 473             right   no early     hit           0           0
# 495             right   no early     hit           0           0
#
# [85 rows x 14 columns]

# %% [markdown]
# ## Making Data Useable

# %%
with NWBHDF5IO("sub-440957_ses-20190213T145027_behavior+ecephys+ogen.nwb", "r") as io:
    read_nwbfile = io.read()
    #for i in 
    #print(read_nwbfile.acquisition["BehavioralEvents"]["trialend_start_times"].timestamps[:4])
    #print(read_nwbfile.acquisition["BehavioralEvents"]["trialend_stop_times"].timestamps[:4])
    pre_start = read_nwbfile.acquisition["BehavioralEvents"]["presample_start_times"].timestamps[:]
    pre_stop = read_nwbfile.acquisition["BehavioralEvents"]["presample_stop_times"].timestamps[:]
    sample_start = read_nwbfile.acquisition["BehavioralEvents"]["sample_start_times"].timestamps[:]
    sample_stop = read_nwbfile.acquisition["BehavioralEvents"]["sample_stop_times"].timestamps[:]
    delay_start = read_nwbfile.acquisition["BehavioralEvents"]["delay_start_times"].timestamps[:]
    delay_stop = read_nwbfile.acquisition["BehavioralEvents"]["delay_stop_times"].timestamps[:]
    go_start = read_nwbfile.acquisition["BehavioralEvents"]["go_start_times"].timestamps[:]
    go_stop = read_nwbfile.acquisition["BehavioralEvents"]["go_stop_times"].timestamps[:]
    
def Clean_data(pre_start,pre_stop,sample_start,sample_stop,delay_start,delay_stop,go_start,go_stop):
    sample_start = np.intersect1d(pre_stop, sample_start)
    sample_stop = np.intersect1d(sample_stop, delay_start)
    delay_start = np.intersect1d(delay_start, sample_stop)
    delay_stop = np.intersect1d(delay_stop, go_start)
    return pre_start,pre_stop,sample_start,sample_stop,delay_start,delay_stop,go_start,go_stop

pre_start,pre_stop,sample_start,sample_stop,delay_start,delay_stop,go_start,go_stop = Clean_data(pre_start,pre_stop,sample_start,sample_stop,delay_start,delay_stop,go_start,go_stop)

# %%
len(delay_start)
# Out:
# 501

# %%
trials_df = trials_df.assign(pre_start = pre_start,
                             pre_stop = pre_stop,
                             sample_start = sample_start,
                             sample_stop = sample_stop,
                             delay_start = delay_start,
                             delay_stop = delay_stop,
                             go_start = go_start,
                             go_stop = go_stop)
trials_df
# Out:
#      start_time  stop_time  trial photostim_onset photostim_power  \
# id
# 0        0.0000     5.2512      1             N/A             N/A
# 1        9.4959    14.3958      2             N/A             N/A
# 2       16.1851    20.9083      3             N/A             N/A
# 3       22.6976    27.5231      4             N/A             N/A
# 4       29.3136    34.2297      5             N/A             N/A
# ..          ...        ...    ...             ...             ...
# 496   3487.0914  3491.8707    497             N/A             N/A
# 497   3494.1904  3499.0391    498             N/A             N/A
# 498   3501.9728  3505.9265    499             N/A             N/A
# 499   3508.2258  3513.2005    500             N/A             N/A
# 500   3516.6514  3521.5281    501             N/A             N/A
#
#     photostim_duration  trial_uid         task  task_protocol  \
# id
# 0                  N/A          1  audio delay              1
# 1                  N/A          2  audio delay              1
# 2                  N/A          3  audio delay              1
# 3                  N/A          4  audio delay              1
# 4                  N/A          5  audio delay              1
# ..                 ...        ...          ...            ...
# 496                N/A        497  audio delay              1
# 497                N/A        498  audio delay              1
# 498                N/A        499  audio delay              1
# 499                N/A        500  audio delay              1
# 500                N/A        501  audio delay              1
#
#     trial_instruction  ... auto_water free_water  pre_start   pre_stop  \
# id                     ...
# 0               right  ...          0          0     0.5000     1.2315
# 1               right  ...          0          0     9.9959    10.8277
# 2               right  ...          0          0    16.6851    17.3805
# 3               right  ...          0          0    23.1976    23.8731
# 4               right  ...          0          0    29.8136    30.6670
# ..                ...  ...        ...        ...        ...        ...
# 496             right  ...          0          0  3487.5914  3488.3438
# 497             right  ...          0          0  3494.6904  3495.5032
# 498              left  ...          0          0  3502.4728  3503.3551
# 499              left  ...          0          0  3508.7258  3509.4934
# 500              left  ...          0          0  3517.1514  3517.8525
#
#      sample_start  sample_stop  delay_start  delay_stop   go_start    go_stop
# id
# 0          1.2315       2.3153       2.3153      3.5153     3.5153     5.0153
# 1         10.8277      11.4777      11.4777     12.6777    12.6777    14.1777
# 2         17.3805      18.0305      18.0305     19.2305    19.2305    20.7305
# 3         23.8731      24.5231      24.5231     25.7231    25.7231    27.2231
# 4         30.6670      31.3170      31.3170     32.5170    32.5170    34.0170
# ..            ...          ...          ...         ...        ...        ...
# 496     3488.3438    3488.9938    3488.9938   3490.1938  3490.1938  3491.6938
# 497     3495.5032    3496.1532    3496.1532   3497.3532  3497.3532  3498.8532
# 498     3503.3551    3504.0051    3504.0051   3505.2051  3505.2051  3506.7051
# 499     3509.4934    3510.1434    3510.1434   3511.3434  3511.3434  3512.8434
# 500     3517.8525    3518.5025    3518.5025   3519.7025  3519.7025  3521.2025
#
# [501 rows x 22 columns]

# %% [markdown]
# ## Spike Rate Plotting

# %%
import ast
units_df['Region'] = units_df.electrodes.apply(lambda x: ast.literal_eval(x.location.values[0])['brain_regions'])
#print(units_df.Region.unique())

trials_Data = trials_df.query("photostim_onset == 'N/A' and outcome == 'hit' ")
units_Data = units_df.query(" Region == 'right ALM' and classification == 'good'")

# %%
units_Data
# Out:
#      unit  sampling_rate unit_quality  unit_posx  unit_posy    unit_amp  \
# id
# 4       4          30000         good       59.0        0.0  406.947115
# 14     15          30000         good       11.0      180.0  109.976708
# 91     98          30000         good       43.0     1060.0   61.662834
# 95    102          30000         good       43.0     1100.0  104.672281
# 102   109          30000         good       11.0     1140.0  248.184540
# 103   110          30000         good       43.0     1140.0  105.489345
# 107   114          30000         good       27.0     1200.0  136.888690
# 109   116          30000         good       11.0     1220.0   64.859592
# 110   117          30000         good       11.0     1220.0   84.273649
# 116   124          30000         good       11.0     1340.0   58.227308
# 117   125          30000         good       11.0     1340.0   70.261493
# 119   127          30000         good       11.0     1420.0  127.472599
# 125   133          30000         good       43.0     1540.0   86.727071
# 127   135          30000         good       11.0     1580.0   63.173354
# 128   136          30000         good       11.0     1580.0  120.807238
# 146   154          30000         good       11.0     1820.0   53.915729
# 152   160          30000        multi       11.0     1980.0  183.082086
# 153   161          30000         good       11.0     1940.0   88.125553
# 157   165          30000         good       59.0     1920.0   93.613911
# 158   166          30000         good       11.0     1940.0  154.160920
# 159   167          30000         good       27.0     1960.0   74.038522
# 167   175          30000        multi       11.0     2020.0  143.692036
# 172   180          30000         good       11.0     2060.0  268.242188
# 173   181          30000         good       43.0     2060.0  106.630805
# 176   185          30000         good       43.0     2100.0   61.638983
# 178   187          30000         good       11.0     2100.0  160.500988
# 179   188          30000         good       11.0     2100.0  131.084848
# 183   193          30000         good       43.0     2140.0   82.722656
# 185   195          30000         good       59.0     2240.0   70.103069
# 189   199          30000         good       11.0     2180.0  150.109294
# 192   202          30000         good       59.0     2200.0  105.982481
# 194   204          30000         good       11.0     2220.0  155.676037
# 197   207          30000         good       27.0     2240.0  144.364506
# 209   219          30000         good       11.0     2340.0  142.753798
# 214   224          30000         good       11.0     2340.0  126.160489
# 215   225          30000         good       11.0     2340.0  310.009552
# 218   228          30000         good       27.0     2360.0  137.622893
# 220   232          30000         good       27.0     2360.0  379.888680
# 222   234          30000         good       11.0     2380.0   79.704484
# 224   237          30000         good       11.0     2380.0  106.060606
# 225   239          30000         good       43.0     2380.0   90.175481
# 226   240          30000         good       59.0     2400.0   55.801548
# 230   244          30000         good       27.0     2440.0   52.335087
# 231   245          30000         good       11.0     2460.0  142.073034
# 232   246          30000        multi       27.0     2440.0  107.718397
# 233   247          30000         good       59.0     2440.0   63.072115
# 259   274          30000         good       59.0     1240.0   58.827329
# 267   282          30000         good       27.0     1960.0   90.846620
# 268   283          30000         good       11.0     2060.0   69.684035
# 273   288          30000         good       11.0     2220.0   81.452357
# 275   290          30000         good       43.0     2220.0  148.155382
# 276   291          30000        multi       27.0     2200.0   48.216361
# 280   295          30000         good       11.0     2340.0  175.544985
# 283   298          30000         good       59.0     2400.0   56.297289
# 286   301          30000         good       43.0     2420.0   62.637917
# 291   306          30000         good       11.0     2460.0   60.900549
#
#       unit_snr  isi_violation  avg_firing_rate  drift_metric  ...  \
# id                                                            ...
# 4    19.863375       0.000000         3.037950      0.503042  ...
# 14    5.275242       0.073159         4.653290      0.112311  ...
# 91    2.976889       0.006073        10.119800      0.168698  ...
# 95    5.831190       0.014125         2.355700      0.247923  ...
# 102  12.069299       0.000000         2.058930      0.167432  ...
# 103   5.075341       0.000000         0.322559      0.074252  ...
# 107   6.707563       0.040672         1.407300      0.138874  ...
# 109   3.812592       0.035535         2.123560      0.204996  ...
# 110   4.517818       0.011373         2.621570      0.211341  ...
# 116   3.191112       0.020985         5.131180      0.212428  ...
# 117   4.466438       0.101588         1.301290      0.371885  ...
# 119   6.760169       0.000000         1.627820      0.380330  ...
# 125   4.748830       0.000000         1.196700      0.255460  ...
# 127   3.747494       0.000000         0.221653      0.065709  ...
# 128   7.223199       0.002573         5.487180      0.474151  ...
# 146   2.817494       0.004081        20.453000      0.285179  ...
# 152   8.759150       1.000000         0.723915      0.288392  ...
# 153   4.144401       0.000000         0.480437      0.219008  ...
# 157   4.392966       0.072045         2.633470      0.177168  ...
# 158   7.542839       0.006086        11.302600      0.671042  ...
# 159   3.340782       0.071082        11.294400      0.572970  ...
# 167   7.136251       0.493588         3.688170      0.547779  ...
# 172  14.004054       0.000000         1.746010      0.459004  ...
# 173   8.392976       0.000000         0.405891      0.124375  ...
# 176   3.923855       0.000635        11.033300      0.630809  ...
# 178   8.283299       0.000000         0.376413      0.118550  ...
# 179   6.601778       0.000000         0.567171      0.180867  ...
# 183   4.242607       0.081909         2.266700      0.118550  ...
# 185   3.889020       0.030658        11.849600      0.025475  ...
# 189   7.535240       0.000000         6.017220      0.499391  ...
# 192   4.998001       0.000000        15.418200      0.618096  ...
# 194   7.242087       0.077268         3.753640      0.608571  ...
# 197   7.903283       0.000000         0.569155      0.131701  ...
# 209   7.856584       0.058485         2.051850      0.466484  ...
# 214   6.600249       0.000000         1.769250      0.648569  ...
# 215  16.483412       0.135322         1.817160      0.352413  ...
# 218   7.264298       0.000000         9.702560      0.366887  ...
# 220  19.295928       0.000000         0.132085      0.068557  ...
# 222   4.311799       0.021504         1.916360      0.640545  ...
# 224   5.994961       0.072636         1.514720      0.365362  ...
# 225   4.702089       0.000000         1.104860      0.489502  ...
# 226   3.280998       0.085429         1.406450      0.571623  ...
# 230   3.319321       0.003031        10.113600      0.738666  ...
# 231   7.935196       0.000000         0.829639      0.395080  ...
# 232   6.176005       1.000000         0.677430      0.217085  ...
# 233   3.584160       0.037345         3.591230      0.518084  ...
# 259   2.951517       0.000000         2.001960      0.246446  ...
# 267   4.186987       0.061874         3.052690      0.286655  ...
# 268   3.340602       0.096129         3.652450      0.400078  ...
# 273   3.962357       1.000000         0.518418      0.138330  ...
# 275   8.641855       0.000000         0.367343      0.149307  ...
# 276   3.270083       0.029327         4.660100      0.027909  ...
# 280   9.264554       0.000000         1.123850      0.500325  ...
# 283   2.996226       0.000000         0.449542      0.147676  ...
# 286   3.504638       0.000000         1.052710      0.207146  ...
# 291   3.424414       0.000000         0.755094      0.386480  ...
#
#      classification                                       anno_name  \
# id
# 4              good                          Dorsal peduncular area
# 14             good                                 Olfactory areas
# 91             good                        Prelimbic area, layer 6b
# 95             good                        Prelimbic area, layer 6b
# 102            good                        Prelimbic area, layer 6a
# 103            good                        Prelimbic area, layer 6a
# 107            good                        Prelimbic area, layer 6a
# 109            good                        Prelimbic area, layer 6a
# 110            good                        Prelimbic area, layer 6a
# 116            good                        Prelimbic area, layer 6a
# 117            good                        Prelimbic area, layer 6a
# 119            good  Anterior cingulate area, dorsal part, layer 6a
# 125            good  Anterior cingulate area, dorsal part, layer 6a
# 127            good                  Secondary motor area, layer 6a
# 128            good                  Secondary motor area, layer 6a
# 146            good                  Secondary motor area, layer 6a
# 152            good                   Secondary motor area, layer 5
# 153            good                   Secondary motor area, layer 5
# 157            good                   Secondary motor area, layer 5
# 158            good                   Secondary motor area, layer 5
# 159            good                   Secondary motor area, layer 5
# 167            good                   Secondary motor area, layer 5
# 172            good                   Secondary motor area, layer 5
# 173            good                   Secondary motor area, layer 5
# 176            good                   Secondary motor area, layer 5
# 178            good                   Secondary motor area, layer 5
# 179            good                   Secondary motor area, layer 5
# 183            good                   Secondary motor area, layer 5
# 185            good                   Secondary motor area, layer 5
# 189            good                   Secondary motor area, layer 5
# 192            good                   Secondary motor area, layer 5
# 194            good                   Secondary motor area, layer 5
# 197            good                   Secondary motor area, layer 5
# 209            good                   Secondary motor area, layer 5
# 214            good                   Secondary motor area, layer 5
# 215            good                   Secondary motor area, layer 5
# 218            good                   Secondary motor area, layer 5
# 220            good                   Secondary motor area, layer 5
# 222            good                   Secondary motor area, layer 5
# 224            good                   Secondary motor area, layer 5
# 225            good                   Secondary motor area, layer 5
# 226            good                   Secondary motor area, layer 5
# 230            good                   Secondary motor area, layer 5
# 231            good                 Secondary motor area, layer 2/3
# 232            good                   Secondary motor area, layer 5
# 233            good                   Secondary motor area, layer 5
# 259            good                        Prelimbic area, layer 6a
# 267            good                   Secondary motor area, layer 5
# 268            good                   Secondary motor area, layer 5
# 273            good                   Secondary motor area, layer 5
# 275            good                   Secondary motor area, layer 5
# 276            good                   Secondary motor area, layer 5
# 280            good                   Secondary motor area, layer 5
# 283            good                   Secondary motor area, layer 5
# 286            good                   Secondary motor area, layer 5
# 291            good                 Secondary motor area, layer 2/3
#
#                                         is_good_trials  \
# id
# 4    [True, True, True, True, True, True, True, Tru...
# 14   [True, True, True, True, True, True, True, Tru...
# 91   [True, True, True, True, True, True, True, Tru...
# 95   [True, True, True, True, True, True, True, Tru...
# 102  [True, True, True, True, True, True, True, Tru...
# 103  [True, True, True, True, True, True, True, Tru...
# 107  [True, True, True, True, True, True, True, Tru...
# 109  [True, True, True, True, True, True, True, Tru...
# 110  [True, True, True, True, True, True, True, Tru...
# 116  [True, True, True, True, True, True, True, Tru...
# 117  [True, True, True, True, True, True, True, Tru...
# 119  [True, True, True, True, True, True, True, Tru...
# 125  [True, True, True, True, True, True, True, Tru...
# 127  [True, True, True, True, True, True, True, Tru...
# 128  [True, True, True, True, True, True, True, Tru...
# 146  [True, True, True, True, True, True, True, Tru...
# 152  [True, True, True, True, True, True, True, Tru...
# 153  [True, True, True, True, True, True, True, Tru...
# 157  [True, True, True, True, True, True, True, Tru...
# 158  [True, True, True, True, True, True, True, Tru...
# 159  [True, True, True, True, True, True, True, Tru...
# 167  [True, True, True, True, True, True, True, Tru...
# 172  [True, True, True, True, True, True, True, Tru...
# 173  [True, True, True, True, True, True, True, Tru...
# 176  [True, True, True, True, True, True, True, Tru...
# 178  [True, True, True, True, True, True, True, Tru...
# 179  [True, True, True, True, True, True, True, Tru...
# 183  [True, True, True, True, True, True, True, Tru...
# 185  [True, True, True, True, True, True, True, Tru...
# 189  [True, True, True, True, True, True, True, Tru...
# 192  [True, True, True, True, True, True, True, Tru...
# 194  [True, True, True, True, True, True, True, Tru...
# 197  [True, True, True, True, True, True, True, Tru...
# 209  [True, True, True, True, True, True, True, Tru...
# 214  [True, True, True, True, True, True, True, Tru...
# 215  [True, True, True, True, True, True, True, Tru...
# 218  [True, True, True, True, True, True, True, Tru...
# 220  [True, True, True, True, True, True, True, Tru...
# 222  [True, True, True, True, True, True, True, Tru...
# 224  [True, True, True, True, True, True, True, Tru...
# 225  [True, True, True, True, True, True, True, Tru...
# 226  [True, True, True, True, True, True, True, Tru...
# 230  [True, True, True, True, True, True, True, Tru...
# 231  [True, True, True, True, True, True, True, Tru...
# 232  [True, True, True, True, True, True, True, Tru...
# 233  [True, True, True, True, True, True, True, Tru...
# 259  [True, True, True, True, True, True, True, Tru...
# 267  [True, True, True, True, True, True, True, Tru...
# 268  [True, True, True, True, True, True, True, Tru...
# 273  [True, True, True, True, True, True, True, Tru...
# 275  [True, True, True, True, True, True, True, Tru...
# 276  [True, True, True, True, True, True, True, Tru...
# 280  [True, True, True, True, True, True, True, Tru...
# 283  [True, True, True, True, True, True, True, Tru...
# 286  [True, True, True, True, True, True, True, Tru...
# 291  [True, True, True, True, True, True, True, Tru...
#
#                                            spike_times  \
# id
# 4    [0.2593131190814475, 0.5323148139669702, 0.702...
# 14   [0.25401308617707663, 0.35208036167807855, 0.4...
# 91   [0.0529451712137714, 0.07537864382158022, 0.10...
# 95   [0.08804538912762405, 3.566700319110314, 10.15...
# 102  [0.1536791299370983, 0.3191468238823649, 1.450...
# 103  [4.15213728703149, 4.727274191006436, 4.965342...
# 107  [0.11057886235627068, 0.19291270684555517, 0.2...
# 109  [0.5356815015351555, 0.7694496195122209, 1.142...
# 110  [0.17591260130323327, 0.31541346737110976, 0.5...
# 116  [1.5014208305001562, 1.5135875727020136, 1.973...
# 117  [55.76206601395983, 93.06266510132917, 93.3756...
# 119  [26.31410366914778, 26.338137151688986, 50.354...
# 125  [3.8009017731110077, 3.9508360372862312, 4.181...
# 127  [0.39298061560048847, 1.0604514261484375, 1.14...
# 128  [80.12497319083771, 80.26150737182076, 80.3644...
# 146  [0.018844959508290238, 0.11434555240780453, 0....
# 152  [0.25264641102563523, 0.27967991219195465, 0.3...
# 153  [1.9588903372900106, 66.51589582921578, 159.34...
# 157  [0.24434635949614858, 0.47794780977181883, 0.6...
# 158  [0.24434635949614858, 0.47794780977181883, 0.6...
# 159  [0.31341345495436634, 0.5924485206303989, 1.08...
# 167  [0.12964564739589424, 0.16961256219049048, 0.2...
# 172  [0.3657137796522152, 58.50858097009853, 77.229...
# 173  [1.0700848192890864, 1.2316524890217027, 2.455...
# 176  [118.33110104548982, 186.80320991352818, 200.1...
# 178  [1.0702181534502024, 1.2317858231828187, 45.25...
# 179  [0.6602489415580122, 1.4568205536067702, 4.435...
# 183  [0.7077159029153974, 0.7252826786424631, 1.364...
# 185  [0.026178338369684084, 0.09211208104167001, 0....
# 189  [3.814368523383749, 12.962635102305427, 19.488...
# 192  [0.03454505697972854, 0.07667865189246381, 0.1...
# 194  [0.03394505325470565, 0.0929120860083672, 0.16...
# 197  [232.593343653096, 234.6892141788505, 235.0685...
# 209  [0.07484530717711557, 0.17567926652127985, 0.1...
# 214  [0.3529137001850553, 0.5388148543213873, 1.407...
# 215  [0.5196814022012055, 1.3840201016372977, 1.643...
# 218  [0.05817853703758402, 0.15334579453430752, 0.1...
# 220  [1.1296518557677713, 3.9352359404356303, 9.731...
# 222  [1.2293858082827263, 1.2988529062242926, 1.369...
# 224  [0.06937860657134909, 0.1878126751828586, 0.28...
# 225  [0.33778027289836077, 43.70876025693659, 44.98...
# 226  [1.2162857269530547, 1.4808873696882534, 2.605...
# 230  [0.04964515072614395, 0.1377456976837066, 0.22...
# 231  [0.9140171837025153, 1.2262524554964944, 1.473...
# 232  [0.6491822061853636, 0.7383827599721347, 0.791...
# 233  [0.03941175386047169, 0.19771273664574007, 0.3...
# 259  [1.484487392038392, 2.081157763033612, 3.76180...
# 267  [1.3020529260910827, 1.4373870996240767, 1.468...
# 268  [0.04214510416335493, 0.14347906661170517, 0.1...
# 273  [17.078986642687905, 20.194339317169092, 27.28...
# 275  [13.74443995601056, 17.522256061318878, 206.12...
# 276  [0.08891206117487993, 0.19887941055550717, 0.5...
# 280  [0.2675131699900972, 1.99055720055512, 2.12729...
# 283  [4.426205655205942, 4.501839458099136, 4.51637...
# 286  [0.026711675014149172, 0.20731279624610988, 0....
# 291  [0.5251147692666924, 0.5388481878616664, 0.664...
#
#                                          obs_intervals  \
# id
# 4    [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 14   [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 91   [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 95   [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 102  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 103  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 107  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 109  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 110  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 116  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 117  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 119  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 125  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 127  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 128  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 146  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 152  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 153  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 157  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 158  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 159  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 167  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 172  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 173  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 176  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 178  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 179  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 183  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 185  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 189  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 192  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 194  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 197  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 209  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 214  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 215  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 218  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 220  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 222  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 224  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 225  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 226  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 230  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 231  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 232  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 233  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 259  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 267  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 268  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 273  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 275  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 276  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 280  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 283  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 286  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
# 291  [[0.0, 5.2512], [9.4959, 14.3958], [16.1851, 2...
#
#                                             electrodes  \
# id
# 4                                                 l...
# 14                                                l...
# 91                                                 ...
# 95                                                 ...
# 102                                                ...
# 103                                                ...
# 107                                                ...
# 109                                                ...
# 110                                                ...
# 116                                                ...
# 117                                                ...
# 119                                                ...
# 125                                                ...
# 127                                                ...
# 128                                                ...
# 146                                                ...
# 152                                                ...
# 153                                                ...
# 157                                                ...
# 158                                                ...
# 159                                                ...
# 167                                                ...
# 172                                                ...
# 173                                                ...
# 176                                                ...
# 178                                                ...
# 179                                                ...
# 183                                                ...
# 185                                                ...
# 189                                                ...
# 192                                                ...
# 194                                                ...
# 197                                                ...
# 209                                                ...
# 214                                                ...
# 215                                                ...
# 218                                                ...
# 220                                                ...
# 222                                                ...
# 224                                                ...
# 225                                                ...
# 226                                                ...
# 230                                                ...
# 231                                                ...
# 232                                                ...
# 233                                                ...
# 259                                                ...
# 267                                                ...
# 268                                                ...
# 273                                                ...
# 275                                                ...
# 276                                                ...
# 280                                                ...
# 283                                                ...
# 286                                                ...
# 291                                                ...
#
#                                        electrode_group  \
# id
# 4    17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 14   17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 91   17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 95   17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 102  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 103  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 107  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 109  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 110  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 116  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 117  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 119  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 125  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 127  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 128  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 146  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 152  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 153  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 157  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 158  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 159  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 167  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 172  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 173  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 176  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 178  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 179  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 183  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 185  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 189  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 192  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 194  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 197  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 209  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 214  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 215  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 218  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 220  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 222  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 224  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 225  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 226  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 230  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 231  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 232  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 233  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 259  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 267  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 268  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 273  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 275  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 276  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 280  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 283  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 286  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
# 291  17131309211 1-301 pynwb.ecephys.ElectrodeGroup...
#
#                                          waveform_mean  waveform_sd     Region
# id
# 4    [10.451923076923077, 9.947115384615385, 9.7596...        [nan]  right ALM
# 14   [-0.016983695652173912, -0.19652562111801242, ...        [nan]  right ALM
# 91   [1.0679183467741935, 1.3112714213709677, 1.240...        [nan]  right ALM
# 95   [1.3367491883116882, 1.1515827922077921, 0.895...        [nan]  right ALM
# 102  [2.0469094162995596, 1.9797976321585904, 1.778...        [nan]  right ALM
# 103  [1.0833150263620386, 1.0668387521968365, 0.416...        [nan]  right ALM
# 107  [0.41540785498489424, 0.28087235649546827, -0....        [nan]  right ALM
# 109  [1.9510405549626466, 1.8259738527214513, 1.833...        [nan]  right ALM
# 110  [1.7077702702702704, 1.7508445945945947, 1.697...        [nan]  right ALM
# 116  [-0.3516854669464848, -0.08853620146904512, 0....        [nan]  right ALM
# 117  [1.259861262241567, 1.0201305767138193, 0.7855...        [nan]  right ALM
# 119  [-0.07828810020876827, -0.16391570981210857, -...        [nan]  right ALM
# 125  [-0.5575073964497042, -0.4382396449704142, -0....        [nan]  right ALM
# 127  [0.5214993606138107, 0.44357416879795397, 0.48...        [nan]  right ALM
# 128  [1.1597688533057853, 1.1912448347107438, 0.992...        [nan]  right ALM
# 146  [3.4599342770475228, 3.1921448432760364, 3.090...        [nan]  right ALM
# 152  [1.4634683098591548, 1.4056998239436618, 1.317...        [nan]  right ALM
# 153  [5.864902712264151, 5.665905070754716, 5.56640...        [nan]  right ALM
# 157  [-0.907258064516129, -1.1315524193548387, -0.9...        [nan]  right ALM
# 158  [4.393649699097292, 4.360738465396189, 4.34428...        [nan]  right ALM
# 159  [-0.08227808425275829, -0.2491850551654965, -0...        [nan]  right ALM
# 167  [3.3064516129032255, 2.847782258064516, 2.8326...        [nan]  right ALM
# 172  [5.071022727272727, 5.172230113636363, 5.19620...        [nan]  right ALM
# 173  [0.9787447625698324, 0.4877356843575419, -0.09...        [nan]  right ALM
# 176  [0.6991366366366366, 0.9009009009009009, 1.313...        [nan]  right ALM
# 178  [1.7472232680722892, 1.6907473644578315, 1.817...        [nan]  right ALM
# 179  [-0.23191529235382308, 0.0, 0.0597357571214392...        [nan]  right ALM
# 183  [1.08515625, 1.07578125, 1.20234375, 1.2328124...        [nan]  right ALM
# 185  [2.101374246987952, 1.8472326807228918, 1.8519...        [nan]  right ALM
# 189  [2.620628238341969, 2.2878886010362693, 2.0717...        [nan]  right ALM
# 192  [0.8877840909090909, 0.868844696969697, 1.0440...        [nan]  right ALM
# 194  [1.9101810253699787, 1.7466635835095137, 1.352...        [nan]  right ALM
# 197  [2.9524253731343286, 2.5221548507462686, 2.123...        [nan]  right ALM
# 209  [2.3929558011049723, 1.8024861878453038, 1.458...        [nan]  right ALM
# 214  [2.8167040358744395, 2.2544142376681617, 1.965...        [nan]  right ALM
# 215  [3.0371520196506547, 2.0162390829694323, 1.814...        [nan]  right ALM
# 218  [-0.6727208886618999, -0.7876340653728294, -1....        [nan]  right ALM
# 220  [5.698430793991417, 5.180391630901288, 4.75791...        [nan]  right ALM
# 222  [2.639751552795031, 2.6640139751552794, 2.3534...        [nan]  right ALM
# 224  [3.2512626262626263, 2.9803240740740744, 2.783...        [nan]  right ALM
# 225  [1.3798076923076923, 0.951923076923077, 0.7956...        [nan]  right ALM
# 226  [1.7229984894259818, 1.6049848942598186, 1.340...        [nan]  right ALM
# 230  [2.2397933467741935, 2.190177671370968, 1.9444...        [nan]  right ALM
# 231  [1.3928022540983607, 1.3039510758196722, 1.460...        [nan]  right ALM
# 232  [0.3205379548306148, 0.35582653701380174, 0.24...        [nan]  right ALM
# 233  [2.182692307692308, 2.295673076923077, 2.03846...        [nan]  right ALM
# 259  [1.2873372027180068, 1.343077576443941, 1.3218...        [nan]  right ALM
# 267  [0.20567602040816327, 0.05022321428571429, -0....        [nan]  right ALM
# 268  [1.1624243951612903, 1.0631930443548387, 1.160...        [nan]  right ALM
# 273  [1.4728483606557377, 1.565061475409836, 1.6342...        [nan]  right ALM
# 275  [1.46484375, 1.26953125, 1.3093171296296295, 1...        [nan]  right ALM
# 276  [0.2857050619834711, -0.15253744834710745, -0....        [nan]  right ALM
# 280  [4.793819304435484, 4.741840977822581, 4.33310...        [nan]  right ALM
# 283  [1.8442622950819674, 1.5398407944514503, 1.545...        [nan]  right ALM
# 286  [-0.5146663078579118, -0.9031889128094726, -1....        [nan]  right ALM
# 291  [1.4516469594594594, 1.5783361486486487, 1.404...        [nan]  right ALM
#
# [56 rows x 40 columns]

# %% [markdown]
# # New data based on Delay range [1.0,1.2]

# %%
trials_Data = trials_Data.query(" (delay_stop - delay_start) > 1 and (delay_stop - delay_start) < 1.3")
trials_Data = trials_Data.query(" (stop_time - start_time) < 5.3")
trials_Data
# Out:
#      start_time  stop_time  trial photostim_onset photostim_power  \
# id
# 0        0.0000     5.2512      1             N/A             N/A
# 1        9.4959    14.3958      2             N/A             N/A
# 2       16.1851    20.9083      3             N/A             N/A
# 4       29.3136    34.2297      5             N/A             N/A
# 12      76.0135    81.0562     13             N/A             N/A
# ..          ...        ...    ...             ...             ...
# 494   3472.0742  3476.9888    495             N/A             N/A
# 496   3487.0914  3491.8707    497             N/A             N/A
# 497   3494.1904  3499.0391    498             N/A             N/A
# 499   3508.2258  3513.2005    500             N/A             N/A
# 500   3516.6514  3521.5281    501             N/A             N/A
#
#     photostim_duration  trial_uid         task  task_protocol  \
# id
# 0                  N/A          1  audio delay              1
# 1                  N/A          2  audio delay              1
# 2                  N/A          3  audio delay              1
# 4                  N/A          5  audio delay              1
# 12                 N/A         13  audio delay              1
# ..                 ...        ...          ...            ...
# 494                N/A        495  audio delay              1
# 496                N/A        497  audio delay              1
# 497                N/A        498  audio delay              1
# 499                N/A        500  audio delay              1
# 500                N/A        501  audio delay              1
#
#     trial_instruction  ... auto_water free_water  pre_start   pre_stop  \
# id                     ...
# 0               right  ...          0          0     0.5000     1.2315
# 1               right  ...          0          0     9.9959    10.8277
# 2               right  ...          0          0    16.6851    17.3805
# 4               right  ...          0          0    29.8136    30.6670
# 12               left  ...          0          0    76.5135    77.2241
# ..                ...  ...        ...        ...        ...        ...
# 494             right  ...          0          0  3472.5742  3473.3628
# 496             right  ...          0          0  3487.5914  3488.3438
# 497             right  ...          0          0  3494.6904  3495.5032
# 499              left  ...          0          0  3508.7258  3509.4934
# 500              left  ...          0          0  3517.1514  3517.8525
#
#      sample_start  sample_stop  delay_start  delay_stop   go_start    go_stop
# id
# 0          1.2315       2.3153       2.3153      3.5153     3.5153     5.0153
# 1         10.8277      11.4777      11.4777     12.6777    12.6777    14.1777
# 2         17.3805      18.0305      18.0305     19.2305    19.2305    20.7305
# 4         30.6670      31.3170      31.3170     32.5170    32.5170    34.0170
# 12        77.2241      77.8741      77.8741     79.0741    79.0741    80.5741
# ..            ...          ...          ...         ...        ...        ...
# 494     3473.3628    3474.0128    3474.0128   3475.2128  3475.2128  3476.7128
# 496     3488.3438    3488.9938    3488.9938   3490.1938  3490.1938  3491.6938
# 497     3495.5032    3496.1532    3496.1532   3497.3532  3497.3532  3498.8532
# 499     3509.4934    3510.1434    3510.1434   3511.3434  3511.3434  3512.8434
# 500     3517.8525    3518.5025    3518.5025   3519.7025  3519.7025  3521.2025
#
# [353 rows x 22 columns]

# %% [markdown]
# # Plotting with phases

# %%
import seaborn as sns
ids = trials_Data.reset_index().id
unit_id = units_Data.reset_index().id
on_times = trials_Data["start_time"]
off_times = trials_Data["stop_time"]
after = 4.3
before = -0.7
spike_data = []
for unit in unit_id[:5]:
    unit_spike_times = units_Data["spike_times"][unit]
    trial_spikes = []
    i = 0
    for time in trials_Data['sample_start']:
        # Compute spike times relative to stimulus onset
        aligned_spikes = unit_spike_times - time
        # Keep only spike times in a given time window around the stimulus onset
        aligned_spikes = aligned_spikes[aligned_spikes < after ]
        i = i+1
        aligned_spikes = aligned_spikes[before < aligned_spikes]
        trial_spikes.append(aligned_spikes)
    fig, axs = plt.subplots(2, 1, sharex="all")
    plt.xlabel("time (s)")
    spike_data.append(trial_spikes)
    
    axs[0].eventplot(trial_spikes)
    axs[0].set_ylabel("trial")
    axs[0].set_title("unit {}".format(unit))
    axs[0].axvline(0, color=[0.5, 0.5, 0.5])
    axs[0].text(0.1,0,'Sample',rotation=90)
    axs[0].axvline(0.65, color=[0.5, 0.5, 0.5])
    axs[0].text(0.75,0,'Delay',rotation=90)
    axs[0].text(1.95,0,'Go',rotation=90)
    axs[0].text(-0.4,0,'Pre-Sample',rotation=90)
    axs[0].axvline(1.85, color=[0.5, 0.5, 0.5])
    axs[0].axvline(3.35, color=[0.5, 0.5, 0.5])
    
    hist, edges = np.histogram(np.hstack(trial_spikes), bins=(np.arange(101)/20) - 1)
    freq = hist/len(trials_Data)*20
    width = np.diff(edges)
    axs[1].bar(edges[1:], freq,width=width)
    
    
#     axs[1].hist(np.hstack(trial_spikes), 30)
    axs[1].set_ylabel("Freq (Hz)")
    axs[1].axvline(0, color=[0.5, 0.5, 0.5])
    axs[1].axvline(0.65, color=[0.5, 0.5, 0.5])
    axs[1].axvline(1.85, color=[0.5, 0.5, 0.5])
    axs[1].axvline(3.35, color=[0.5, 0.5, 0.5])
    #sns.kdeplot(ax=axs[1], data=np.hstack(trial_spikes))

# %%
hist, edges = np.histogram(np.hstack(spike_data[0]), bins=(np.arange(101)/20) - 1)
freq = (hist/len(trials_Data))*20
width = np.diff(edges)
smooth_gauss = []

#plt.plot(edges[1:], freq)
for i in edges[1:]:
    gauss = np.exp((- ( edges[1:] - i) ** 2) / ( 2 * (0.1**2) ) )
    gauss /=  sum(gauss)
    smooth_gauss.append(sum(gauss*freq))
plt.plot(edges[1:],smooth_gauss)
plt.plot(edges[1:],freq)

# %%
def get_smooth_gauss(spike_data,sigma,color,dataset):
    hist, edges = np.histogram(np.hstack(spike_data), bins=(np.arange(101)/20) - 1)
    freq = (hist/len(dataset))*20
    width = np.diff(edges)
    smooth_gauss = []

    for i in edges[1:]:
        gauss = np.exp((- ( edges[1:] - i) ** 2) / ( 2 * (sigma**2) ) )
        gauss /=  sum(gauss)
        smooth_gauss.append(sum(gauss*freq))
    plt.plot(edges[1:],smooth_gauss,color=color)
    #plt.plot(edges[1:],freq)
    
    #return freq,edges[1:],smooth_gauss
    
def return_smooth_gauss(spike_data,sigma,dataset):
    hist, edges = np.histogram(np.hstack(spike_data), bins=(np.arange(101)/20) - 1)
    freq = (hist/len(dataset))*20
    width = np.diff(edges)
    smooth_gauss = []

    for i in edges[1:]:
        gauss = np.exp((- ( edges[1:] - i) ** 2) / ( 2 * (sigma**2) ) )
        gauss /=  sum(gauss)
        smooth_gauss.append(sum(gauss*freq))
    
    return freq,edges[1:],smooth_gauss

# %%
# for i in spike_data:
#     fig, axs = plt.subplots(1, 1, sharex="all")
#     freq,edges,smooth_gauss = get_smooth_gauss(i,0.1,'r')

# %%
trials_Data_L = trials_Data[ trials_Data['trial_instruction'] == 'left']
trials_Data_R = trials_Data[ trials_Data['trial_instruction'] == 'right']

def get_firing_rate_graph(Trial_Data1,Trial_Data2,sigma):
    after = 4.35
    before = -0.7
    spike_data = []
    
    for unit in units_Data.reset_index().id[:5]:
        unit_spike_times = units_Data["spike_times"][unit]
        trial_spikes_l = []
        trial_spikes_r = []
        i = 0
        for time in Trial_Data1['sample_start']:
            # Compute spike times relative to stimulus onset
            aligned_spikes1 = unit_spike_times - time
            # Keep only spike times in a given time window around the stimulus onset
            aligned_spikes1 = aligned_spikes1[aligned_spikes1 < after ]
            aligned_spikes1 = aligned_spikes1[before < aligned_spikes1]
            trial_spikes_l.append(aligned_spikes1)
            
        for time in Trial_Data2['sample_start']:
            # Compute spike times relative to stimulus onset
            aligned_spikes = unit_spike_times - time
            # Keep only spike times in a given time window around the stimulus onset
            aligned_spikes = aligned_spikes[aligned_spikes < after ]
            aligned_spikes = aligned_spikes[before < aligned_spikes]
            trial_spikes_r.append(aligned_spikes)            
            
        fig, axs = plt.subplots(1, 1, sharex="all")
        
        
        plt.xlabel("time (s)")
        
        get_smooth_gauss(trial_spikes_l,sigma,'r',trials_Data_L)
        get_smooth_gauss(trial_spikes_r,sigma,'b',trials_Data_R)
        axs.set_ylabel("Freq (Hz)")
        axs.axvline(0, color=[0.5, 0.5, 0.5])
        axs.axvline(0.65, color=[0.5, 0.5, 0.5])
        axs.axvline(1.85, color=[0.5, 0.5, 0.5])
        axs.axvline(3.35, color=[0.5, 0.5, 0.5])
        
        axs.text(0.1,0,'Sample',rotation=90)
        axs.text(0.75,0,'Delay',rotation=90)
        axs.text(1.95,0,'Go',rotation=90)
        axs.text(-0.4,0,'Pre-Sample',rotation=90)
get_firing_rate_graph(trials_Data_L,trials_Data_R,0.05)

# %%
len(trials_Data_L),len(trials_Data_R)
# Out:
# (191, 162)

# %%
def get_firing_rate_over_neurons(Trial_Data1,Trial_Data2,sigma):
    after = 4.3
    before = -0.7
    spike_data_l = []
    spike_data_r = []
    
    for unit in units_Data.reset_index()['id']:
        unit_spike_times = units_Data["spike_times"][unit]
        trial_spikes_l = []
        trial_spikes_r = []
        i = 0
        for time in Trial_Data1['sample_start']:
            # Compute spike times relative to stimulus onset
            aligned_spikes = unit_spike_times - time
            # Keep only spike times in a given time window around the stimulus onset
            aligned_spikes = aligned_spikes[aligned_spikes < after ]
            aligned_spikes = aligned_spikes[before < aligned_spikes]
            trial_spikes_l.append(aligned_spikes)
            
        frq_l,edge,smooth_l = return_smooth_gauss(trial_spikes_l,sigma,trials_Data_L)    
        spike_data_l.append(smooth_l)
            
        for time in Trial_Data2['sample_start']:
            # Compute spike times relative to stimulus onset
            aligned_spikes = unit_spike_times - time
            # Keep only spike times in a given time window around the stimulus onset
            aligned_spikes = aligned_spikes[aligned_spikes < after ]
            aligned_spikes = aligned_spikes[before < aligned_spikes]
            trial_spikes_r.append(aligned_spikes)
            
        frq_r,edge,smooth_r = return_smooth_gauss(trial_spikes_r,sigma,trials_Data_R)    
        spike_data_r.append(smooth_r)    
        
    return spike_data_l,spike_data_r,edge

l,r,edges = get_firing_rate_over_neurons(trials_Data_L,trials_Data_R,0.1)

# %%
# avg_left_rate = np.array(l).mean(axis=0)
# avg_right_rate = np.array(r).mean(axis=0)


# fig, axs = plt.subplots(1, 1, sharex="all")
# axs.plot(edges,avg_left_rate,c='r')
# axs.plot(edges,avg_right_rate,c='b')
# axs.axvline(0, color=[0.5, 0.5, 0.5])
# axs.axvline(0.65, color=[0.5, 0.5, 0.5])
# axs.axvline(1.85, color=[0.5, 0.5, 0.5])
# axs.axvline(3.35, color=[0.5, 0.5, 0.5])

# axs.text(0.1,0,'Sample',rotation=90)
# axs.text(0.75,0,'Delay',rotation=90)
# axs.text(1.95,0,'Go',rotation=90)
# axs.text(-0.4,0,'Pre-Sample',rotation=90)
# axs.set_ylabel("Freq (Hz)")
# axs.legend(['Left','Right'])
# plt.show()

# %%
diff_cd = (np.array(r)-np.array(l))
delay_avg_diff = diff_cd[:,32:57].mean(axis=1)
newly_l = np.array(l).T.dot(delay_avg_diff)
newly_r = np.array(r).T.dot(delay_avg_diff)

# %%
#Delay period CD Apply (Yet to finish)    (**FINISHED**)
# diff_cd = (np.array(l)-np.array(r)).mean(axis=1)
# newly_l = np.array(l).T.dot(diff_cd)
# newly_r = np.array(r).T.dot(diff_cd)

# %%
fig, axs = plt.subplots(1, 1, sharex="all")
axs.plot(edges,newly_l,c='r')
axs.plot(edges,newly_r,c='b')
axs.axvline(0, color=[0.5, 0.5, 0.5])
axs.axvline(0.65, color=[0.5, 0.5, 0.5])
axs.axvline(1.85, color=[0.5, 0.5, 0.5])
axs.axvline(3.35, color=[0.5, 0.5, 0.5])

# axs.text(0.1,-3000,'Sample',rotation=90)
# axs.text(0.75,-3000,'Delay',rotation=90)
# axs.text(1.95,-3000,'Go',rotation=90)
# axs.text(-0.4,-3000,'Pre-Sample',rotation=90)
axs.set_ylabel("Trajectory (a.u.)")
axs.tick_params(labelleft = False)
axs.legend(['Left','Right'])
plt.show()

# %% [markdown]
# # Distribution during delay and go phase

# %%
def get_phases_rate_graph(Trial_Data1,Trial_Data2,sigma):

    spike_data = []
    
    for unit in units_Data.reset_index().id:
        unit_spike_times = units_Data["spike_times"][unit]
        trial_spikes_go_l = []
        trial_spikes_go_r = []
        trial_spikes_delay_l = []
        trial_spikes_delay_r = []
        trial_sample_l = []
        trial_sample_r = []
        
    
        for time in Trial_Data1['sample_start']:
            # Compute spike times relative to stimulus onset
            
            after = 3.35
            before = 1.85
            aligned_spikes1 = unit_spike_times - time
            # Keep only spike times in a given time window around the stimulus onset
            aligned_spikes1 = aligned_spikes1[aligned_spikes1 < after ]
            aligned_spikes1 = aligned_spikes1[before < aligned_spikes1]
            trial_spikes_go_l.append(aligned_spikes1)
            
            after = 1.85
            before = 0.65
            aligned_spikes1 = unit_spike_times - time
            # Keep only spike times in a given time window around the stimulus onset
            aligned_spikes1 = aligned_spikes1[aligned_spikes1 < after ]
            aligned_spikes1 = aligned_spikes1[before < aligned_spikes1]
            trial_spikes_delay_l.append(aligned_spikes1)
            
            after = 0.65
            before = 0
            aligned_spikes1 = unit_spike_times - time
            # Keep only spike times in a given time window around the stimulus onset
            aligned_spikes1 = aligned_spikes1[aligned_spikes1 < after ]
            aligned_spikes1 = aligned_spikes1[before < aligned_spikes1]
            trial_sample_l.append(aligned_spikes1)
            
        for time in Trial_Data2['sample_start']:
            # Compute spike times relative to stimulus onset
            
            after = 3.35
            before = 1.85
            aligned_spikes1 = unit_spike_times - time
            # Keep only spike times in a given time window around the stimulus onset
            aligned_spikes1 = aligned_spikes1[aligned_spikes1 < after ]
            aligned_spikes1 = aligned_spikes1[before < aligned_spikes1]
            trial_spikes_go_r.append(aligned_spikes1)
            
            after = 1.85
            before = 0.65
            aligned_spikes1 = unit_spike_times - time
            # Keep only spike times in a given time window around the stimulus onset
            aligned_spikes1 = aligned_spikes1[aligned_spikes1 < after ]
            aligned_spikes1 = aligned_spikes1[before < aligned_spikes1]
            trial_spikes_delay_r.append(aligned_spikes1)        
            
            after = 0.65
            before = 0
            aligned_spikes1 = unit_spike_times - time
            # Keep only spike times in a given time window around the stimulus onset
            aligned_spikes1 = aligned_spikes1[aligned_spikes1 < after ]
            aligned_spikes1 = aligned_spikes1[before < aligned_spikes1]
            trial_sample_r.append(aligned_spikes1)   
              
    return trial_sample_l, trial_sample_r, trial_spikes_go_l,trial_spikes_go_r,trial_spikes_delay_l,trial_spikes_delay_r     

def get_freq_edge(spike_data,dataset):
    hist, edges = np.histogram(np.hstack(spike_data), bins=(np.arange(31)/20) + 1.80)
    freq = (hist/len(dataset))*20
    return freq,edges[1:]

def get_freq_edge_1(spike_data,dataset):
    hist, edges = np.histogram(np.hstack(spike_data), bins=(np.arange(25)/20) + 0.60)
    freq = (hist/len(dataset))*20
    return freq,edges[1:]

def get_freq_edge_2(spike_data,dataset):
    hist, edges = np.histogram(np.hstack(spike_data), bins=(np.arange(14)/20) + 0)
    freq = (hist/len(dataset))*20
    return freq,edges[1:]


sample_l, sample_r, go_l,go_r,delay_l,delay_r = get_phases_rate_graph(trials_Data_L,trials_Data_R,0.1)
freq_sample_l,edges2 = get_freq_edge_2(sample_l,trials_Data_L)
freq_sample_r,edges2 = get_freq_edge_2(sample_r,trials_Data_R)
freq_go_l,edges = get_freq_edge(go_l,trials_Data_L)
freq_go_r,edges = get_freq_edge(go_r,trials_Data_R)
freq_delay_l,edges1 = get_freq_edge_1(delay_l,trials_Data_L)
freq_delay_r,edges1 = get_freq_edge_1(delay_r,trials_Data_R)

# %%
#Delay vs Go(Phases vs Phases)(Yet to finish)
sns.kdeplot(freq_go_l + freq_go_r, c='b')
sns.kdeplot(freq_delay_l + freq_delay_r, c='r')
sns.kdeplot(freq_sample_l + freq_sample_r, c='black')
# Out:
# <AxesSubplot:ylabel='Density'>
