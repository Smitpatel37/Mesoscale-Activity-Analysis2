# %%
from pynwb import NWBHDF5IO, NWBFile, TimeSeries
from pynwb.behavior import Position, SpatialSeries
from pynwb.epoch import TimeIntervals
from pynwb.file import Subject
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import animation
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from itertools import count
import ast
import scipy.io
import os
import pickle

#Projection zones file
mat = scipy.io.loadmat('D:\\Mesoscale-Activity-Analysis/MAT/medialALM_mask_150um3Dgauss_Bilateral.mat')  #FOR CHECKING OVERLAP WITH THALAMUS
vox = mat['F_smooth']

# %%
### Get times and clean data


def Clean_data(file, alltrials):
    with NWBHDF5IO(file, "r") as io:

        read_nwbfile = io.read()
        pre_start = read_nwbfile.acquisition["BehavioralEvents"]["presample_start_times"].timestamps[:]
        pre_stop = read_nwbfile.acquisition["BehavioralEvents"]["presample_stop_times"].timestamps[:]
        sample_start = read_nwbfile.acquisition["BehavioralEvents"]["sample_start_times"].timestamps[:]
        sample_stop = read_nwbfile.acquisition["BehavioralEvents"]["sample_stop_times"].timestamps[:]
        delay_start = read_nwbfile.acquisition["BehavioralEvents"]["delay_start_times"].timestamps[:]
        delay_stop = read_nwbfile.acquisition["BehavioralEvents"]["delay_stop_times"].timestamps[:]
        go_start = read_nwbfile.acquisition["BehavioralEvents"]["go_start_times"].timestamps[:]
        go_stop = read_nwbfile.acquisition["BehavioralEvents"]["go_stop_times"].timestamps[:]
    
    sample_start = np.intersect1d(pre_stop, sample_start)
    sample_stop = np.intersect1d(sample_stop, delay_start)
    delay_start = np.intersect1d(delay_start, sample_stop)
    delay_stop = np.intersect1d(delay_stop, go_start)
    # Add epoch's Start-Stop time pair to each trial
    alltrials_clean = alltrials.assign(pre_start = pre_start,
                             pre_stop = pre_stop,
                             sample_start = pre_stop,
                             sample_stop = sample_stop,
                             delay_start = delay_start,
                             delay_stop = delay_stop,
                             go_start = go_start,
                             go_stop = go_stop)
    return alltrials_clean


def select_units(units, region):
    ### unit specification (specify region, only good units, etc)
    units['Region'] = units.electrodes.apply(lambda x: ast.literal_eval(x.location.values[0])['brain_regions']) ## adds column "Region"
    units_Data = units.query(f" Region == '{region}' ")
    units_Data = units_Data.query(" unit_quality == 'good'")
    return units_Data
    
def select_trials(alltrials_clean,lick_dir):
    #### trial specification (e.g., only hit, no early, etc)
    trials_Data = alltrials_clean.query("outcome == 'hit' ")
    trials_Data = trials_Data.query("early_lick == 'no early'")
    trials_Data = trials_Data.query(f" trial_instruction == '{lick_dir}' ")
    return trials_Data

# %%
def overview_units():
    import os 
    path = 'D:\\Mesoscale-Activity-Analysis\\NWBdata'
    os.chdir(path)
    sub_id = []
    ses_id = []
    for dir1 in os.listdir():
        if not dir1.startswith('a'):
            print(dir1[4:])
            sub_id+=[dir1]
            os.chdir((path+'/'+dir1))
            for file in (os.listdir()):
                if not file.startswith('a'):
                    print(file)
                    ses_id+=[file[15:30]]
                    ### load units and trials
                    io = NWBHDF5IO(file, "r") 
                    nwbfile = io.read()
                    units = nwbfile.units.to_dataframe()
                    units_region = units.electrodes.apply(lambda x: ast.literal_eval(x.location.values[0])['brain_regions']).value_counts()
                    print(units_region)
overview_units()
# Out:
# 440956
# sub-440956_ses-20190207T120657_behavior+ecephys+ogen.nwb
# electrodes
# left ALM          674
# right Striatum    489
# right ALM         409
# left Striatum     380
# Name: count, dtype: int64
# sub-440956_ses-20190208T133600_behavior+ecephys+ogen.nwb
# electrodes
# left ALM          534
# left Striatum     456
# right ALM         397
# right Striatum    348
# Name: count, dtype: int64
# sub-440956_ses-20190209T150135_behavior+ecephys+ogen.nwb
# electrodes
# left Striatum     677
# right Striatum    478
# Name: count, dtype: int64
# sub-440956_ses-20190210T155629_behavior+ecephys+ogen.nwb
# electrodes
# right Striatum    680
# left ALM          600
# right ALM         506
# left Striatum     225
# Name: count, dtype: int64
# 440957
# sub-440957_ses-20190211T143614_behavior+ecephys+ogen.nwb
# electrodes
# left Striatum     617
# left ALM          602
# right ALM         511
# right Striatum    380
# Name: count, dtype: int64
# sub-440957_ses-20190212T153751_behavior+ecephys+ogen.nwb
# electrodes
# left ALM          753
# right Striatum    466
# left Striatum     421
# right ALM         389
# Name: count, dtype: int64
# sub-440957_ses-20190213T145027_behavior+ecephys+ogen.nwb
# electrodes
# right Striatum    359
# left Striatum     315
# right ALM         293
# Name: count, dtype: int64
# sub-440957_ses-20190214T144611_behavior+ecephys+ogen.nwb
# electrodes
# right Striatum    395
# left ALM          366
# right ALM         107
# Name: count, dtype: int64
# 440958
# sub-440958_ses-20190213T115547_behavior+ecephys+ogen.nwb
# electrodes
# left Striatum     488
# right ALM         456
# left ALM          272
# right Striatum    144
# Name: count, dtype: int64
# sub-440958_ses-20190214T123412_behavior+ecephys+ogen.nwb
# electrodes
# right ALM         635
# right Striatum    406
# left ALM          372
# left Striatum     283
# Name: count, dtype: int64
# sub-440958_ses-20190215T141028_behavior+ecephys+ogen.nwb
# electrodes
# right ALM         572
# left ALM          508
# right Striatum    347
# left Striatum     134
# Name: count, dtype: int64
# 441666
# sub-441666_ses-20190513T144253_behavior+ecephys+ogen.nwb
# electrodes
# left Midbrain     524
# left ALM          378
# right Midbrain    374
# right ALM         299
# Name: count, dtype: int64
# sub-441666_ses-20190514T154424_behavior+ecephys+ogen.nwb
# electrodes
# left Midbrain     577
# right Midbrain    566
# left ALM          371
# right ALM         234
# Name: count, dtype: int64
# sub-441666_ses-20190515T153723_behavior+ecephys+ogen.nwb
# electrodes
# right Midbrain    565
# left Midbrain     405
# right ALM         310
# left ALM          278
# Name: count, dtype: int64
# sub-441666_ses-20190516T152922_behavior+ecephys+ogen.nwb
# electrodes
# right ALM         621
# right Midbrain    514
# left Midbrain     417
# left ALM          415
# Name: count, dtype: int64
# sub-441666_ses-20190517T150543_behavior+ecephys+ogen.nwb
# electrodes
# right Midbrain    417
# left Midbrain     412
# right ALM         365
# left ALM          247
# Name: count, dtype: int64
# 442571
# sub-442571_ses-20190227T134351_behavior+ecephys+ogen.nwb
# electrodes
# right Striatum    472
# left Striatum     401
# left ALM          290
# right ALM         266
# Name: count, dtype: int64
# sub-442571_ses-20190228T140832_behavior+ecephys+ogen.nwb
# electrodes
# right Striatum    633
# left ALM          584
# right ALM         500
# left Striatum     420
# Name: count, dtype: int64
# sub-442571_ses-20190301T140324_behavior+ecephys+ogen.nwb
# electrodes
# left Striatum     467
# left ALM          459
# right ALM         338
# right Striatum    328
# Name: count, dtype: int64
# sub-442571_ses-20190302T150148_behavior+ecephys+ogen.nwb
# electrodes
# left ALM          450
# left Striatum     435
# right Striatum    396
# right ALM         393
# Name: count, dtype: int64
# sub-442571_ses-20190303T144606_behavior+ecephys+ogen.nwb
# electrodes
# left Striatum     574
# right Striatum    499
# left ALM          420
# right ALM         255
# Name: count, dtype: int64
# 449141
# left Thalamus_ccf_locs sub-449141_ses-20190603T160047.pkl
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[27], line 22
#      20                     units_region = units.electrodes.apply(lambda x: ast.literal_eval(x.location.values[0])['brain_regions']).value_counts()
#      21                     print(units_region)
# ---> 22 overview_units()
#
# Cell In[27], line 17, in overview_units()
#      15 ses_id+=[file[15:30]]
#      16 ### load units and trials
# ---> 17 io = NWBHDF5IO(file, "r")
#      18 nwbfile = io.read()
#      19 units = nwbfile.units.to_dataframe()
#
# File ~\anaconda3\Lib\site-packages\hdmf\utils.py:668, in docval.<locals>.dec.<locals>.func_call(*args, **kwargs)
#     666 def func_call(*args, **kwargs):
#     667     pargs = _check_args(args, kwargs)
# --> 668     return func(args[0], **pargs)
#
# File ~\anaconda3\Lib\site-packages\pynwb\__init__.py:309, in NWBHDF5IO.__init__(self, **kwargs)
#     307 if load_namespaces:
#     308     tm = get_type_map()
# --> 309     super().load_namespaces(tm, path, file=file_obj, driver=driver, aws_region=aws_region)
#     310     manager = BuildManager(tm)
#     312     # XXX: Leaving this here in case we want to revert to this strategy for
#     313     #      loading cached namespaces
#     314     # ns_catalog = NamespaceCatalog(NWBGroupSpec, NWBDatasetSpec, NWBNamespace)
#    (...)
#     317     # tm.copy_mappers(get_type_map())
#     318 else:
#
# File ~\anaconda3\Lib\site-packages\hdmf\utils.py:668, in docval.<locals>.dec.<locals>.func_call(*args, **kwargs)
#     666 def func_call(*args, **kwargs):
#     667     pargs = _check_args(args, kwargs)
# --> 668     return func(args[0], **pargs)
#
# File ~\anaconda3\Lib\site-packages\hdmf\backends\hdf5\h5tools.py:185, in HDF5IO.load_namespaces(cls, **kwargs)
#     174 """Load cached namespaces from a file.
#     175
#     176 If `file` is not supplied, then an :py:class:`h5py.File` object will be opened for the given `path`, the
#    (...)
#     180 :raises ValueError: if both `path` and `file` are supplied but `path` is not the same as the path of `file`.
#     181 """
#     182 namespace_catalog, path, namespaces, file_obj, driver, aws_region = popargs(
#     183     'namespace_catalog', 'path', 'namespaces', 'file', 'driver', 'aws_region', kwargs)
# --> 185 open_file_obj = cls.__resolve_file_obj(path, file_obj, driver, aws_region=aws_region)
#     186 if file_obj is None:  # need to close the file object that we just opened
#     187     with open_file_obj:
#
# File ~\anaconda3\Lib\site-packages\hdmf\backends\hdf5\h5tools.py:158, in HDF5IO.__resolve_file_obj(cls, path, file_obj, driver, aws_region)
#     156         if aws_region is not None:
#     157             file_kwargs.update(aws_region=bytes(aws_region, "ascii"))
# --> 158     file_obj = File(path, 'r', **file_kwargs)
#     159 return file_obj
#
# File ~\anaconda3\Lib\site-packages\h5py\_hl\files.py:562, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     553     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     554                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     555                      alignment_threshold=alignment_threshold,
#     556                      alignment_interval=alignment_interval,
#     557                      meta_block_size=meta_block_size,
#     558                      **kwds)
#     559     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     560                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     561                      fs_page_size=fs_page_size)
# --> 562     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     564 if isinstance(libver, tuple):
#     565     self._libver = libver
#
# File ~\anaconda3\Lib\site-packages\h5py\_hl\files.py:235, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     233     if swmr and swmr_support:
#     234         flags |= h5f.ACC_SWMR_READ
# --> 235     fid = h5f.open(name, flags, fapl=fapl)
#     236 elif mode == 'r+':
#     237     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py\\_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py\\_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py\\h5f.pyx:102, in h5py.h5f.open()
#
# OSError: Unable to open file (file signature not found)

# %%
def get_pooledandsegmented(units_Data, trials_Data):
    
#### get spikes with pooled and segmented trials between -3 and 3

    '''
    
    spikes_pooled: all spikes from units_Data are pooled (no trial distinction)
    spikes_segmented: spikes are segmented into trials, as defined by trials_Data
    
    time 0 represents the GO cue
    each trial is defined by before<time<after
    '''

    after = 1.5
    before = -2.5

    spikes_pooled = []
    spikes_segmented = []
    units = []
    x,y,z=[],[],[]
    for unit in units_Data.reset_index()['id']:
        #print('unit', unit)
        unit_spike_times = units_Data["spike_times"][unit]
        trial_spikes = []
        spikes_pooled.append(unit_spike_times)
        for index_time, time in enumerate(trials_Data['go_start'].values):
            #print('time', time)
            # Compute spike times relative to go signal
            aligned_spikes = unit_spike_times - time
            # pre_go = time - trials_Data['pre_start'].values[index_time]
            # post_go = trials_Data['go_stop'].values[index_time]-time
            #print('pre_go', pre_go)
            #print('post_go', post_go)
            aligned_spikes = aligned_spikes[aligned_spikes < after]
            aligned_spikes = aligned_spikes[before < aligned_spikes]
            trial_spikes.append(aligned_spikes) 
        
        spikes_segmented.append(trial_spikes)
    # print("shape pooled spikes", np.shape(spikes_pooled))
    # print("shape segmented spikes", np.shape(spikes_segmented))
    return spikes_pooled, spikes_segmented

def get_pooledandsegmented_Pre(units_Data, trials_Data):
    
#### get spikes with pooled and segmented trials between -1.5 and 1.5

    '''
    
    spikes_pooled: all spikes from units_Data are pooled (no trial distinction)
    spikes_segmented: spikes are segmented into trials, as defined by trials_Data
    
    time 0 represents the Presample cue
    each trial is defined by before<time<after
    '''

    after = 1.5
    before = -1.5

    spikes_pooled = []
    spikes_segmented = []
    for unit in units_Data.reset_index()['id']:
        #print('unit', unit)
        unit_spike_times = units_Data["spike_times"][unit]
        trial_spikes = []
        spikes_pooled.append(unit_spike_times)
        for index_time, time in enumerate(trials_Data['pre_start'].values):
            #print('time', time)
            # Compute spike times relative to go signal
            aligned_spikes = unit_spike_times - time
            pre_go = time - trials_Data['pre_start'].values[index_time]
            post_go = trials_Data['go_stop'].values[index_time]-time
            #print('pre_go', pre_go)
            #print('post_go', post_go)
            aligned_spikes = aligned_spikes[aligned_spikes < after]
            aligned_spikes = aligned_spikes[before < aligned_spikes]
            trial_spikes.append(aligned_spikes)
        spikes_segmented.append(trial_spikes)
        
    spikes_pooled = np.array(spikes_pooled, dtype=object)
    spikes_segmented = np.array(spikes_segmented, dtype=object)
    
    print("shape pooled spikes", np.shape(spikes_pooled))
    print("shape segmented spikes", np.shape(spikes_segmented))
    return spikes_pooled, spikes_segmented


#### CROSS CHECK THOSE 2 FUNCTION , SOMEHING RELATED TO INDEXING CAN BE MODIFY AND MAKE IT EASIER
def ccf(units_Data, unit_number):
    x = float(units_Data.electrodes[unit_number].reset_index().x.values)
    y = float(units_Data.electrodes[unit_number].reset_index().y.values)
    z = float(units_Data.electrodes[unit_number].reset_index().z.values)
    return x, y, z

def get_CCF(units_Data):
    x,y,z = [],[],[]
    unit_num = []
    for unit in units_Data.reset_index()['id']:
        unit_num.append(units_Data.unit[unit])
        try:
            x_ccf, y_ccf, z_ccf = ccf(units_Data,unit)
            x.append(x_ccf)
            y.append(y_ccf)
            z.append(z_ccf)
        
        # Some Units have missing CCF locations
        except Exception as err:
            x.append(0)
            y.append(0)
            z.append(0)
    return zip(x,y,z),unit_num

def export_ccf(locs,units,region, *idparams):
    sub_id, session_id = idparams
    path = 'D:\\Mesoscale-Activity-Analysis\\NWBdata\\'+'sub-'+str(sub_id)+'/analysis'
    os.chdir(path)
    with open(str(region)+'_'+'sub-'+str(sub_id)+'_ses-'+str(session_id)+'_CCF_Allunits.pkl', 'wb') as f:  # open a text file
        pickle.dump(zip(locs,units), f)

# %%
def get_stats(trials_Data):
    ##### get stats to calculate selectivity
    trials_hit = trials_Data.query("outcome=='hit'").trial.values.astype("float")#np.unique((units_subject_ALM_session&{'early_lick':'no early'}&{'outcome':'hit'}).fetch('trial'))
    trials_miss = trials_Data.query("outcome=='miss'").trial.values.astype("float")#np.unique((units_subject_ALM_session&{'early_lick':'no early'}&{'outcome':'miss'}).fetch('trial'))
    trials_ignore = trials_Data.query("outcome=='ignore'").trial.values.astype("float")#np.unique((units_subject_ALM_session&{'outcome':'ignore'}).fetch('trial'))
    trials_early = trials_Data.query("early_lick=='early'").trial.values.astype("float")#np.unique((units_subject_ALM_session&{'early_lick':'early'}).fetch('trial'))
    left_hit =  trials_Data.query("trial_instruction=='left' and outcome=='hit' ").trial.values.astype("float")#np.unique((units_subject_ALM_session&{'early_lick':'no early'}&{'outcome':'hit'}&{'trial_instruction':'left'}).fetch('trial'))
    right_hit = trials_Data.query("trial_instruction=='right' and outcome=='hit' ").trial.values.astype("float")#np.unique((units_subject_ALM_session&{'early_lick':'no early'}&{'outcome':'hit'}&{'trial_instruction':'right'}).fetch('trial'))

    hit = len(trials_hit)
    miss = len(trials_miss)
    ignore = len(trials_ignore)
    early = len(trials_early)
    combinedtrials = trials_Data.trial.values.astype("float")
    '''print('hit', hit)
    print('miss',miss)
    print('ignore', ignore)
    print('early', early)
    print('percentcorrect', hit/(hit+miss))
    print('left_trials', len(left_hit))
    print('right_trials', len(right_hit))
    '''
    stats = [hit, miss, ignore, early, combinedtrials, left_hit, right_hit]
    return stats

def export_neuraldata(spikes_pooled, spikes_segmented,Unit_Data,region, *idparams):
    import os
    import pickle
    sub_id, session_id = idparams 
    path = 'D:\\Mesoscale-Activity-Analysis\\NWBdata\\'+'sub-'+str(sub_id)+'/analysis'
    os.chdir(path)
    ###### EXPORT DATA##########
    with open(str(region)+'_notrials'+'sub-'+str(sub_id)+'_ses-'+str(session_id)+'_allunits_right.pkl', 'wb') as f:  # open a text file
        pickle.dump(spikes_pooled, f) # 
    with open(region+'_withtrials'+'sub-'+str(sub_id)+'_ses-'+str(session_id)+'_allunits_right.pkl', 'wb') as f:  # open a text file
        pickle.dump(spikes_segmented, f) 

    #df = pd.DataFrame(Unit_Data)
    #df.to_hdf(region+'sub-'+str(sub_id)+'_ses-'+str(session_id)+'_unitInfo.h5',key=mode='w') 

def export_Overlap_neuraldata(spikes_pooled, spikes_segmented,Unit_Data,region, *idparams):
    import os
    import pickle
    sub_id, session_id = idparams 
    path = 'D:\\Mesoscale-Activity-Analysis\\NWBdata\\'+'sub-'+str(sub_id)+'/analysis'
    os.chdir(path)
    ###### EXPORT DATA##########
    with open(str(region)+'_notrials'+'sub-'+str(sub_id)+'_ses-'+str(session_id)+'_Pre_Overlap_units.pkl', 'wb') as f:  # open a text file
        pickle.dump(spikes_pooled, f) # 
    with open(region+'_withtrials'+'sub-'+str(sub_id)+'_ses-'+str(session_id)+'_Pre_Overlap_units.pkl', 'wb') as f:  # open a text file
        pickle.dump(spikes_segmented, f) # 
    #with open(region+'sub-'+str(sub_id)+'_ses-'+str(session_id)+'_Overlap_unitInfo.pkl', 'wb') as f:  # open a text file
    #    pickle.dump(Unit_Data.electrodes, f)
        
def export_stats(stats,*idparams):
    import os
    import pickle
    sub_id, session_id = idparams 
    path = 'D:\\Mesoscale-Activity-Analysis\\NWBdata/'+'sub-'+str(sub_id)+'/analysis'
    os.chdir(path)
    ###### EXPORT DATA##########
    with open('session'+str(session_id)+'_sub'+str(sub_id)+'_stats.pkl', 'wb') as f: 
         pickle.dump(stats, f) # 


def get_data_allfiles(regions):
    
    '''
    Main function. It exports data related to statistics (e.g., hit, miss, etc.), spikes_pooled, spikes_segmented

    Input
    
    regions: set of regions to get the units data from
    
    '''
    import warnings
    warnings.filterwarnings('ignore')
    import os 
    path = 'D:\\Mesoscale-Activity-Analysis\\NWBdata'
    os.chdir(path) 
    for dir1 in os.listdir():
        if not dir1.startswith('a'):
            print('dir', dir1)
            sub_id = dir1[4:]
            os.chdir((path+'/'+dir1))
            for file in (os.listdir()):
                if file.endswith(".nwb"):
                    session_id= file[15:30]
                    datafile = file
                    print('working directory', os.getcwd())
                    print('datafile', datafile)
                    ### load NWB data
                    os.chdir((path+'/'+dir1))
                    io = NWBHDF5IO(datafile, "r") 
                    nwbfile = io.read()
                    ### load units and trials
                    units = nwbfile.units.to_dataframe()
                    alltrials = nwbfile.trials.to_dataframe()
                    alltrials_clean = Clean_data(file, alltrials)
                    trials_Data = select_trials(alltrials_clean,'right')
                    # stats = get_stats(trials_Data)
                    idparams = sub_id, session_id
                    # export_stats(stats, *idparams)
                    if (select_units(units, regions[0]).empty==False and select_units(units, regions[1]).empty==False):
                        print(str(session_id)+" has left ALM and Thalamus recording")
                        for region in regions:
                            units_Data = select_units(units, region)
                            if units_Data.empty==False:
                                spikes_pooled, spikes_segmented = get_pooledandsegmented(units_Data, trials_Data)
                                # locs,unit_num = get_CCF(units_Data)
                                print('session', session_id)
                                print('region',region)
                                print(type(region))
                                # export_ccf(locs,unit_num,region, *idparams)
                                export_neuraldata(spikes_pooled, spikes_segmented,units_Data, region, *idparams)
                                print('export complete for file ', file)
                                print()
                    else:
                        print(str(session_id)+" has no recording")
get_data_allfiles(['left ALM','left Thalamus'])
# Out:
# dir sub-440956
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-440956
# datafile sub-440956_ses-20190207T120657_behavior+ecephys+ogen.nwb
# 20190207T120657 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-440956
# datafile sub-440956_ses-20190208T133600_behavior+ecephys+ogen.nwb
# 20190208T133600 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-440956
# datafile sub-440956_ses-20190209T150135_behavior+ecephys+ogen.nwb
# 20190209T150135 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-440956
# datafile sub-440956_ses-20190210T155629_behavior+ecephys+ogen.nwb
# 20190210T155629 has no recording
# dir sub-440957
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-440957
# datafile sub-440957_ses-20190211T143614_behavior+ecephys+ogen.nwb
# 20190211T143614 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-440957
# datafile sub-440957_ses-20190212T153751_behavior+ecephys+ogen.nwb
# 20190212T153751 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-440957
# datafile sub-440957_ses-20190213T145027_behavior+ecephys+ogen.nwb
# 20190213T145027 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-440957
# datafile sub-440957_ses-20190214T144611_behavior+ecephys+ogen.nwb
# 20190214T144611 has no recording
# dir sub-440958
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-440958
# datafile sub-440958_ses-20190213T115547_behavior+ecephys+ogen.nwb
# 20190213T115547 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-440958
# datafile sub-440958_ses-20190214T123412_behavior+ecephys+ogen.nwb
# 20190214T123412 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-440958
# datafile sub-440958_ses-20190215T141028_behavior+ecephys+ogen.nwb
# 20190215T141028 has no recording
# dir sub-441666
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-441666
# datafile sub-441666_ses-20190513T144253_behavior+ecephys+ogen.nwb
# 20190513T144253 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-441666
# datafile sub-441666_ses-20190514T154424_behavior+ecephys+ogen.nwb
# 20190514T154424 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-441666
# datafile sub-441666_ses-20190515T153723_behavior+ecephys+ogen.nwb
# 20190515T153723 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-441666
# datafile sub-441666_ses-20190516T152922_behavior+ecephys+ogen.nwb
# 20190516T152922 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-441666
# datafile sub-441666_ses-20190517T150543_behavior+ecephys+ogen.nwb
# 20190517T150543 has no recording
# dir sub-442571
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-442571
# datafile sub-442571_ses-20190227T134351_behavior+ecephys+ogen.nwb
# 20190227T134351 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-442571
# datafile sub-442571_ses-20190228T140832_behavior+ecephys+ogen.nwb
# 20190228T140832 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-442571
# datafile sub-442571_ses-20190301T140324_behavior+ecephys+ogen.nwb
# 20190301T140324 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-442571
# datafile sub-442571_ses-20190302T150148_behavior+ecephys+ogen.nwb
# 20190302T150148 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-442571
# datafile sub-442571_ses-20190303T144606_behavior+ecephys+ogen.nwb
# 20190303T144606 has no recording
# dir sub-449141
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-449141
# datafile sub-449141_ses-20190530T173316_behavior+ecephys+ogen.nwb
# 20190530T173316 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-449141
# datafile sub-449141_ses-20190531T161406_behavior+ecephys+ogen.nwb
# 20190531T161406 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-449141
# datafile sub-449141_ses-20190601T175411_behavior+ecephys+ogen.nwb
# 20190601T175411 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-449141
# datafile sub-449141_ses-20190602T155210_behavior+ecephys+ogen.nwb
# 20190602T155210 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-449141
# datafile sub-449141_ses-20190603T160047_behavior+ecephys+ogen.nwb
# 20190603T160047 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-449141
# datafile sub-449141_ses-20190604T152447_behavior+ecephys+ogen.nwb
# 20190604T152447 has no recording
# dir sub-455219
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-455219
# datafile sub-455219_ses-20190805T152117_behavior+ecephys+ogen.nwb
# 20190805T152117 has left ALM and Thalamus recording
# session 20190805T152117
# region left ALM
# <class 'str'>
# export complete for file  sub-455219_ses-20190805T152117_behavior+ecephys+ogen.nwb
#
# session 20190805T152117
# region left Thalamus
# <class 'str'>
# export complete for file  sub-455219_ses-20190805T152117_behavior+ecephys+ogen.nwb
#
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-455219\analysis
# datafile sub-455219_ses-20190806T143015_behavior+ecephys+ogen.nwb
# 20190806T143015 has left ALM and Thalamus recording
# session 20190806T143015
# region left ALM
# <class 'str'>
# export complete for file  sub-455219_ses-20190806T143015_behavior+ecephys+ogen.nwb
#
# session 20190806T143015
# region left Thalamus
# <class 'str'>
# export complete for file  sub-455219_ses-20190806T143015_behavior+ecephys+ogen.nwb
#
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-455219\analysis
# datafile sub-455219_ses-20190807T134913_behavior+ecephys+ogen.nwb
# 20190807T134913 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-455219
# datafile sub-455219_ses-20190808T140448_behavior+ecephys+ogen.nwb
# 20190808T140448 has left ALM and Thalamus recording
# session 20190808T140448
# region left ALM
# <class 'str'>
# export complete for file  sub-455219_ses-20190808T140448_behavior+ecephys+ogen.nwb
#
# session 20190808T140448
# region left Thalamus
# <class 'str'>
# export complete for file  sub-455219_ses-20190808T140448_behavior+ecephys+ogen.nwb
#
# dir sub-455220
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-455220
# datafile sub-455220_ses-20190729T145044_behavior+ecephys+ogen.nwb
# 20190729T145044 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-455220
# datafile sub-455220_ses-20190730T154125_behavior+ecephys+ogen.nwb
# 20190730T154125 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-455220
# datafile sub-455220_ses-20190731T151805_behavior+ecephys+ogen.nwb
# 20190731T151805 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-455220
# datafile sub-455220_ses-20190801T135056_behavior+ecephys+ogen.nwb
# 20190801T135056 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-455220
# datafile sub-455220_ses-20190803T150200_behavior+ecephys+ogen.nwb
# 20190803T150200 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-455220
# datafile sub-455220_ses-20190804T152922_behavior+ecephys+ogen.nwb
# 20190804T152922 has no recording
# dir sub-456772
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-456772
# datafile sub-456772_ses-20191119T115109_behavior+ecephys+ogen.nwb
# 20191119T115109 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-456772
# datafile sub-456772_ses-20191119T130822_behavior+ecephys+ogen.nwb
# 20191119T130822 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-456772
# datafile sub-456772_ses-20191120T115527_behavior+ecephys+ogen.nwb
# 20191120T115527 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-456772
# datafile sub-456772_ses-20191120T130334_behavior+ecephys+ogen.nwb
# 20191120T130334 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-456772
# datafile sub-456772_ses-20191121T113844_behavior+ecephys+ogen.nwb
# 20191121T113844 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-456772
# datafile sub-456772_ses-20191121T124405_behavior+ecephys+ogen.nwb
# 20191121T124405 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-456772
# datafile sub-456772_ses-20191122T134226_behavior+ecephys+ogen.nwb
# 20191122T134226 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-456772
# datafile sub-456772_ses-20191122T144855_behavior+ecephys+ogen.nwb
# 20191122T144855 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-456772
# datafile sub-456772_ses-20191123T135013_behavior+ecephys+ogen.nwb
# 20191123T135013 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-456772
# datafile sub-456772_ses-20191123T145127_behavior+ecephys+ogen.nwb
# 20191123T145127 has no recording
# dir sub-479149
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-479149
# datafile sub-479149_ses-20201209T115448_behavior+ecephys.nwb
# 20201209T115448 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-479149
# datafile sub-479149_ses-20201210T113111_behavior+ecephys+ogen.nwb
# 20201210T113111 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-479149
# datafile sub-479149_ses-20201211T110651_behavior+ecephys.nwb
# 20201211T110651 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-479149
# datafile sub-479149_ses-20201214T120340_behavior+ecephys.nwb
# 20201214T120340 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-479149
# datafile sub-479149_ses-20201216T120333_behavior+ecephys+ogen.nwb
# 20201216T120333 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-479149
# datafile sub-479149_ses-20201217T120512_behavior+ecephys+ogen.nwb
# 20201217T120512 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-479149
# datafile sub-479149_ses-20201218T113815_behavior+ecephys+ogen.nwb
# 20201218T113815 has no recording
# dir sub-480133
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-480133
# datafile sub-480133_ses-20201224T122322_behavior+ecephys.nwb
# 20201224T122322 has left ALM and Thalamus recording
# session 20201224T122322
# region left ALM
# <class 'str'>
# export complete for file  sub-480133_ses-20201224T122322_behavior+ecephys.nwb
#
# session 20201224T122322
# region left Thalamus
# <class 'str'>
# export complete for file  sub-480133_ses-20201224T122322_behavior+ecephys.nwb
#
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-480133\analysis
# datafile sub-480133_ses-20201225T114244_behavior+ecephys+ogen.nwb
# 20201225T114244 has left ALM and Thalamus recording
# session 20201225T114244
# region left ALM
# <class 'str'>
# export complete for file  sub-480133_ses-20201225T114244_behavior+ecephys+ogen.nwb
#
# session 20201225T114244
# region left Thalamus
# <class 'str'>
# export complete for file  sub-480133_ses-20201225T114244_behavior+ecephys+ogen.nwb
#
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-480133\analysis
# datafile sub-480133_ses-20201226T121710_behavior+ecephys+ogen.nwb
# 20201226T121710 has left ALM and Thalamus recording
# session 20201226T121710
# region left ALM
# <class 'str'>
# export complete for file  sub-480133_ses-20201226T121710_behavior+ecephys+ogen.nwb
#
# session 20201226T121710
# region left Thalamus
# <class 'str'>
# export complete for file  sub-480133_ses-20201226T121710_behavior+ecephys+ogen.nwb
#
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-480133\analysis
# datafile sub-480133_ses-20201229T125330_behavior+ecephys.nwb
# 20201229T125330 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-480133
# datafile sub-480133_ses-20201230T112558_behavior+ecephys+ogen.nwb
# 20201230T112558 has left ALM and Thalamus recording
# session 20201230T112558
# region left ALM
# <class 'str'>
# export complete for file  sub-480133_ses-20201230T112558_behavior+ecephys+ogen.nwb
#
# session 20201230T112558
# region left Thalamus
# <class 'str'>
# export complete for file  sub-480133_ses-20201230T112558_behavior+ecephys+ogen.nwb
#
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-480133\analysis
# datafile sub-480133_ses-20201231T114638_behavior+ecephys+ogen.nwb
# 20201231T114638 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-480133
# datafile sub-480133_ses-20210101T123136_behavior+ecephys+ogen.nwb
# 20210101T123136 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-480133
# datafile sub-480133_ses-20210103T133044_behavior+ecephys+ogen.nwb
# 20210103T133044 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-480133
# datafile sub-480133_ses-20210104T131503_behavior+ecephys+ogen.nwb
# 20210104T131503 has no recording
# dir sub-480134
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-480134
# datafile sub-480134_ses-20210106T125834_behavior+ecephys+ogen.nwb
# 20210106T125834 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-480134
# datafile sub-480134_ses-20210107T120825_behavior+ecephys+ogen.nwb
# 20210107T120825 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-480134
# datafile sub-480134_ses-20210108T135220_behavior+ecephys+ogen.nwb
# 20210108T135220 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-480134
# datafile sub-480134_ses-20210110T134005_behavior+ecephys+ogen.nwb
# 20210110T134005 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-480134
# datafile sub-480134_ses-20210111T122809_behavior+ecephys+ogen.nwb
# 20210111T122809 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-480134
# datafile sub-480134_ses-20210112T130202_behavior+ecephys+ogen.nwb
# 20210112T130202 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-480134
# datafile sub-480134_ses-20210113T125455_behavior+ecephys+ogen.nwb
# 20210113T125455 has left ALM and Thalamus recording
# session 20210113T125455
# region left ALM
# <class 'str'>
# export complete for file  sub-480134_ses-20210113T125455_behavior+ecephys+ogen.nwb
#
# session 20210113T125455
# region left Thalamus
# <class 'str'>
# export complete for file  sub-480134_ses-20210113T125455_behavior+ecephys+ogen.nwb
#
# dir sub-480135
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-480135
# datafile sub-480135_ses-20210225T155426_behavior+ecephys+ogen.nwb
# 20210225T155426 has left ALM and Thalamus recording
# session 20210225T155426
# region left ALM
# <class 'str'>
# export complete for file  sub-480135_ses-20210225T155426_behavior+ecephys+ogen.nwb
#
# session 20210225T155426
# region left Thalamus
# <class 'str'>
# export complete for file  sub-480135_ses-20210225T155426_behavior+ecephys+ogen.nwb
#
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-480135\analysis
# datafile sub-480135_ses-20210226T161028_behavior+ecephys+ogen.nwb
# 20210226T161028 has left ALM and Thalamus recording
# session 20210226T161028
# region left ALM
# <class 'str'>
# export complete for file  sub-480135_ses-20210226T161028_behavior+ecephys+ogen.nwb
#
# session 20210226T161028
# region left Thalamus
# <class 'str'>
# export complete for file  sub-480135_ses-20210226T161028_behavior+ecephys+ogen.nwb
#
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-480135\analysis
# datafile sub-480135_ses-20210227T131716_behavior+ecephys+ogen.nwb
# 20210227T131716 has left ALM and Thalamus recording
# session 20210227T131716
# region left ALM
# <class 'str'>
# export complete for file  sub-480135_ses-20210227T131716_behavior+ecephys+ogen.nwb
#
# session 20210227T131716
# region left Thalamus
# <class 'str'>
# export complete for file  sub-480135_ses-20210227T131716_behavior+ecephys+ogen.nwb
#
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-480135\analysis
# datafile sub-480135_ses-20210301T144130_behavior+ecephys+ogen.nwb
# 20210301T144130 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-480135
# datafile sub-480135_ses-20210302T140243_behavior+ecephys+ogen.nwb
# 20210302T140243 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-480135
# datafile sub-480135_ses-20210303T161010_behavior+ecephys+ogen.nwb
# 20210303T161010 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-480135
# datafile sub-480135_ses-20210304T163309_behavior+ecephys+ogen.nwb
# 20210304T163309 has no recording
# dir sub-480927
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-480927
# datafile sub-480927_ses-20210218T122535_behavior+ecephys+ogen.nwb
# 20210218T122535 has left ALM and Thalamus recording
# session 20210218T122535
# region left ALM
# <class 'str'>
# export complete for file  sub-480927_ses-20210218T122535_behavior+ecephys+ogen.nwb
#
# session 20210218T122535
# region left Thalamus
# <class 'str'>
# export complete for file  sub-480927_ses-20210218T122535_behavior+ecephys+ogen.nwb
#
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-480927\analysis
# datafile sub-480927_ses-20210219T132453_behavior+ecephys+ogen.nwb
# 20210219T132453 has left ALM and Thalamus recording
# session 20210219T132453
# region left ALM
# <class 'str'>
# export complete for file  sub-480927_ses-20210219T132453_behavior+ecephys+ogen.nwb
#
# session 20210219T132453
# region left Thalamus
# <class 'str'>
# export complete for file  sub-480927_ses-20210219T132453_behavior+ecephys+ogen.nwb
#
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-480927\analysis
# datafile sub-480927_ses-20210220T124834_behavior+ecephys+ogen.nwb
# 20210220T124834 has left ALM and Thalamus recording
# session 20210220T124834
# region left ALM
# <class 'str'>
# export complete for file  sub-480927_ses-20210220T124834_behavior+ecephys+ogen.nwb
#
# session 20210220T124834
# region left Thalamus
# <class 'str'>
# export complete for file  sub-480927_ses-20210220T124834_behavior+ecephys+ogen.nwb
#
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-480927\analysis
# datafile sub-480927_ses-20210221T130859_behavior+ecephys+ogen.nwb
# 20210221T130859 has left ALM and Thalamus recording
# session 20210221T130859
# region left ALM
# <class 'str'>
# export complete for file  sub-480927_ses-20210221T130859_behavior+ecephys+ogen.nwb
#
# session 20210221T130859
# region left Thalamus
# <class 'str'>
# export complete for file  sub-480927_ses-20210221T130859_behavior+ecephys+ogen.nwb
#
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-480927\analysis
# datafile sub-480927_ses-20210222T130313_behavior+ecephys+ogen.nwb
# 20210222T130313 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-480927
# datafile sub-480927_ses-20210223T135753_behavior+ecephys+ogen.nwb
# 20210223T135753 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-480927
# datafile sub-480927_ses-20210224T133042_behavior+ecephys+ogen.nwb
# 20210224T133042 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-480927
# datafile sub-480927_ses-20210225T115002_behavior+ecephys+ogen.nwb
# 20210225T115002 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-480927
# datafile sub-480927_ses-20210226T133429_behavior+ecephys+ogen.nwb
# 20210226T133429 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-480927
# datafile sub-480927_ses-20210228T131818_behavior+ecephys+ogen.nwb
# 20210228T131818 has no recording
# dir sub-480928
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-480928
# datafile sub-480928_ses-20210121T153333_behavior+ecephys+ogen.nwb
# 20210121T153333 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-480928
# datafile sub-480928_ses-20210122T131850_behavior+ecephys+ogen.nwb
# 20210122T131850 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-480928
# datafile sub-480928_ses-20210123T132015_behavior+ecephys+ogen.nwb
# 20210123T132015 has no recording
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-480928
# datafile sub-480928_ses-20210125T124258_behavior+ecephys+ogen.nwb
# 20210125T124258 has left ALM and Thalamus recording
# session 20210125T124258
# region left ALM
# <class 'str'>
# export complete for file  sub-480928_ses-20210125T124258_behavior+ecephys+ogen.nwb
#
# session 20210125T124258
# region left Thalamus
# <class 'str'>
# export complete for file  sub-480928_ses-20210125T124258_behavior+ecephys+ogen.nwb
#
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-480928\analysis
# datafile sub-480928_ses-20210126T134951_behavior+ecephys+ogen.nwb
# 20210126T134951 has left ALM and Thalamus recording
# session 20210126T134951
# region left ALM
# <class 'str'>
# export complete for file  sub-480928_ses-20210126T134951_behavior+ecephys+ogen.nwb
#
# session 20210126T134951
# region left Thalamus
# <class 'str'>
# export complete for file  sub-480928_ses-20210126T134951_behavior+ecephys+ogen.nwb
#
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-480928\analysis
# datafile sub-480928_ses-20210127T140737_behavior+ecephys+ogen.nwb
# 20210127T140737 has left ALM and Thalamus recording
# session 20210127T140737
# region left ALM
# <class 'str'>
# export complete for file  sub-480928_ses-20210127T140737_behavior+ecephys+ogen.nwb
#
# session 20210127T140737
# region left Thalamus
# <class 'str'>
# export complete for file  sub-480928_ses-20210127T140737_behavior+ecephys+ogen.nwb
#
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-480928\analysis
# datafile sub-480928_ses-20210128T133949_behavior+ecephys+ogen.nwb
# 20210128T133949 has left ALM and Thalamus recording
# session 20210128T133949
# region left ALM
# <class 'str'>
# export complete for file  sub-480928_ses-20210128T133949_behavior+ecephys+ogen.nwb
#
# session 20210128T133949
# region left Thalamus
# <class 'str'>
# export complete for file  sub-480928_ses-20210128T133949_behavior+ecephys+ogen.nwb
#
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-480928\analysis
# datafile sub-480928_ses-20210129T132207_behavior+ecephys+ogen.nwb
# 20210129T132207 has left ALM and Thalamus recording
# session 20210129T132207
# region left ALM
# <class 'str'>
# export complete for file  sub-480928_ses-20210129T132207_behavior+ecephys+ogen.nwb
#
# session 20210129T132207
# region left Thalamus
# <class 'str'>
# export complete for file  sub-480928_ses-20210129T132207_behavior+ecephys+ogen.nwb
#
# working directory D:\Mesoscale-Activity-Analysis\NWBdata\sub-480928\analysis
# datafile sub-480928_ses-20210130T135022_behavior+ecephys+ogen.nwb
# 20210130T135022 has no recording

# %%
####OLD
####EXPORT units with all trials pooled, segmented and stats

### load NWB data
io = NWBHDF5IO(file, "r") 
nwbfile = io.read()
### load units and trials
units = nwbfile.units.to_dataframe()
alltrials = nwbfile.trials.to_dataframe()

alltrials_clean = Clean_data(file)
units_Data, trials_Data = selectunitsandtrials(units, alltrials_clean)
###### EXPORT DATA##########

import pickle

with open('unitsALM_notrials'+'sub-'+str(sub_id)+'_ses-'+str(session_id)+'_allunits.pkl', 'wb') as f:  # open a text file
    pickle.dump(spikes_pooled, f) # 
with open('unitsALM_withtrials'+'sub-'+str(sub_id)+'_ses-'+str(session_id)+'_allunits.pkl', 'wb') as f:  # open a text file
    pickle.dump(spikes_segmented, f) # 
#with open('unitsThal_notrials_session'+str(session_id)+'_sub'+str(sub_id)+'_allunits.pkl', 'wb') as f:  # open a text file
    #pickle.dump(spikes_pooled_th, f) 
with open('session'+str(session_id)+'_sub'+str(sub_id)+'_stats.pkl', 'wb') as f: 
     pickle.dump(stats, f) #
